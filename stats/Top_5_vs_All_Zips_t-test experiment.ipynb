# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
all_zips = pd.read_csv('zillow_home_value_mapping_.csv')

# %%
#read in all top 5 boro zips and compare it to all zips 

manhattan_top5 = pd.read_csv('./zipcode_data/top_zipcodes/manhattan_top_zipcode_home_value.csv')
brooklyn_top5 = pd.read_csv('./zipcode_data/top_zipcodes/brooklyn_top_zipcode_home_value.csv')
staten_island_top5 = pd.read_csv('./zipcode_data/top_zipcodes/staten_island_top_zipcode_home_value.csv')
bronx_top5 = pd.read_csv('./zipcode_data/top_zipcodes/bronx_top_zipcode_home_value.csv')
queens_top5 = pd.read_csv('./zipcode_data/top_zipcodes/queens_top_zipcode_home_value.csv')

# %%
manhattan_top5
# Out:
#    zipcode    borough  year  count    home_value
# 0    10013  MANHATTAN  2019   1779  3.310300e+06
# 1    10024  MANHATTAN  2019   1721  1.726462e+06
# 2    10018  MANHATTAN  2018   2485  1.463682e+06
# 3    10003  MANHATTAN  2017   2184  1.402998e+06
# 4    10009  MANHATTAN  2017   2593  1.091941e+06

# %%
all_zips
# Out:
#        zipcode state      city    borough  year  home_value
# 0        11368    NY  New York     QUEENS  2015    417755.0
# 1        11385    NY  New York     QUEENS  2015    537186.0
# 2        11236    NY  New York   BROOKLYN  2015    401310.0
# 3        11208    NY  New York   BROOKLYN  2015    396395.0
# 4        10467    NY  New York      BRONX  2015    278072.0
# ...        ...   ...       ...        ...   ...         ...
# 16572    10464    NY  New York      BRONX  2022    609781.0
# 16573    10004    NY  New York  MANHATTAN  2022   1081807.0
# 16574    10006    NY  New York  MANHATTAN  2022    902566.0
# 16575    11243    NY  New York   BROOKLYN  2022   1426544.0
# 16576    10118    NY  New York  MANHATTAN  2022   2867150.0
#
# [16577 rows x 6 columns]

# %%
bronx_top5
# Out:
#    zipcode borough  year  count     home_value
# 0    10469   BRONX  2022    122  592184.800000
# 1    10466   BRONX  2022    119  560980.300000
# 2    10466   BRONX  2021     99  528377.083333
# 3    10456   BRONX  2022     98  454902.900000
# 4    10463   BRONX  2018    105  357383.416667

# %%
boroughs1 = bronx_top5["borough"]
zip_codes1 = bronx_top5["zipcode"]
home_values1 = bronx_top5["home_value"]
year1 = 2020

# Calculate group mean and standard deviation for first dataset
mean1 = np.mean(home_values1)
std1 = np.std(home_values1)
size1 = len(home_values1)

# %%
print(mean1,"this is mean")
print(std1,"this is standard deviation")
print(size1,"this is total of all homes")
# Out:
# 498765.7 this is mean
# 84127.89547500944 this is standard deviation
# 5 this is total of all homes

# %%
# Preset mean value for comparison
preset_mean = 498765

# %%
# Calculate T-statistic for first dataset
t1 = (mean1 - preset_mean) / (std1 / np.sqrt(size1))
print(f"T-statistic for first dataset:", t1)
# Out:
# T-statistic for first dataset: 1.8605571617334086e-05

# %%
# Sample data for second dataset
boroughs2 = all_zips["borough"]
zip_codes2 = all_zips["zipcode"]
home_values2 = all_zips["home_value"]
year2 = 2020

# Calculate group mean and standard deviation for first dataset
mean2 = np.mean(home_values2)
std2 = np.std(home_values2)
size2 = len(home_values2)

# %%
print(mean2,"this is mean")
print(std2,"this is standard deviation")
print(size2,"this is total of all homes")
# Out:
# 838426.3414972553 this is mean
# 508135.13476499007 this is standard deviation
# 16577 this is total of all homes

# %%
# Calculate T-statistic for second dataset
t2 = (mean2 - preset_mean) / (std2 / np.sqrt(size2))
print(f"T-statistic for second dataset:", t2)
# Out:
# T-statistic for second dataset: 86.06367050115905

# %%
import numpy as np

# Sample data for first dataset
boroughs1 = ["Manhattan", "Bronx", "Brooklyn", "Queens", "Staten Island"]
zip_codes1 = [10001, 10451, 11211, 11354, 10314]
home_values1 = all_zips["home_value"]
year1 = 2020

# Calculate group mean and standard deviation for first dataset
mean1 = np.mean(home_values1)
std1 = np.std(home_values1)
size1 = len(home_values1)

# Preset mean value for comparison
preset_mean = 750000

# Calculate T-statistic for first dataset
t1 = (mean1 - preset_mean) / (std1 / np.sqrt(size1))
print(f"T-statistic for first dataset: {t1:.3f}")

# Sample data for second dataset
boroughs2 = ["Manhattan", "Bronx", "Brooklyn", "Queens", "Staten Island"]
zip_codes2 = [10001, 10451, 11211, 11354, 10314, 10465, 11206, 11106, 11432, 11373]
home_values2 = [1000000, 500000, 800000, 700000, 600000, 400000, 600000, 500000, 400000, 500000]
year2 = 2020

# Calculate group mean and standard deviation for second dataset
mean2 = np.mean(home_values2)
std2 = np.std(home_values2)
size2 = len(home_values2)

# Calculate T-statistic for second dataset
t2 = (mean2 - preset_mean) / (std2 / np.sqrt(size2))
print(f"T-statistic for second dataset: {t2:.3f}")

# %%
# Sample data for first dataset
boroughs1 = ["Manhattan", "Bronx", "Brooklyn", "Queens", "Staten Island"]
zip_codes1 = [10001, 10451, 11211, 11354, 10314]
home_values1 = [1000000, 500000, 800000, 700000, 600000]
year1 = 2020

# Calculate group mean and standard deviation for first dataset
mean1 = np.mean(home_values1)
std1 = np.std(home_values1)
size1 = len(home_values1)

# Preset mean value for comparison
preset_mean = 750000

# Calculate T-statistic for first dataset
t1 = (mean1 - preset_mean) / (std1 / np.sqrt(size1))
print(f"T-statistic for first dataset: {t1:.3f}")

# Sample data for second dataset
boroughs2 = ["Manhattan", "Bronx", "Brooklyn", "Queens", "Staten Island"]
zip_codes2 = [10001, 10451, 11211, 11354, 10314, 10465, 11206, 11106, 11432, 11373]
home_values2 = [1000000, 500000, 800000, 700000, 600000, 400000, 600000, 500000, 400000, 500000]
year2 = 2020

# Calculate group mean and standard deviation for second dataset
mean2 = np.mean(home_values2)
std2 = np.std(home_values2)
size2 = len(home_values2)

# Calculate T-statistic for second dataset
t2 = (mean2 - preset_mean) / (std2 / np.sqrt(size2))
print(f"T-statistic for second dataset: {t2:.3f}")
# Out:
# T-statistic for first dataset: -0.390
# T-statistic for second dataset: -2.652

# %%
airbnb = pd.read_csv("../data/clean/inside_airbnb_clean.gz")

# %%
airbnb
# Out:
#               id last_scraped    host_id host_name       neighbourhood  \
# 0           2539   2022-09-07       2787      John          Kensington
# 1           5121   2022-09-07       7356     Garon  Bedford-Stuyvesant
# 2          45910   2022-09-07     204539      Mark           Ridgewood
# 3           5136   2022-09-07       7378   Rebecca         Sunset Park
# 4          45935   2022-09-07     204586         L          Mott Haven
# ...          ...          ...        ...       ...                 ...
# 335498  46937371   2020-01-01   27181542        Jt            Kips Bay
# 335499  46937954   2020-01-01  287807769     Allen     Upper West Side
# 335500  46938514   2020-01-01  303319010    Naiomy         East Harlem
# 335501  46938537   2020-01-01    3351317     Clara            Kips Bay
# 335502  46941857   2020-01-01   13603829       Kay            Bushwick
#
#         latitude  longitude        room_type  bedrooms  availability_365  \
# ...
