# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import random

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Using cached bs4-0.0.1-py3-none-any.whl
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.11.1 bs4-0.0.1 soupsieve-2.3.2.post1

# %%
"""Extracts HTML from a webpage""" 
def scrape_page(page_url):
    answer = requests.get(page_url)
    soup = BeautifulSoup(answer.content, features='html.parser')
    return soup

# %%
"""
Return soup object from url_obj 
where url_obj is:
{page_num <int> : href <str>}
e.g {1: "www.airbnb.com/1/"}

"""
def extract_listing(url_obj):
    page_url = ""
    pag_key = ""
    for key in url_obj:
        page_url = url_obj[key]
        page_key = key
    """Extracts listings from an Airbnb search page"""
    page_soup = scrape_page(page_url)
    formatted_date =  datetime.fromtimestamp(datetime.now().timestamp())
    print("Extracted Data: {}--{}\t".format(page_url, formatted_date))
    return page_soup

# %%
soup = extract_listing({1: "https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=september&flexible_trip_dates%5B%5D=october&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&adults=0&children=0&infants=0&pets=0&search_type=AUTOSUGGEST"})
# Out:
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=september&flexible_trip_dates%5B%5D=october&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&adults=0&children=0&infants=0&pets=0&search_type=AUTOSUGGEST--2022-12-04 00:23:29.463847

# %%
"""
soup: page soup object
className: attribute id that has anchor tag
count: page number count we are currently extracting
"""
def extract_anchors(soup, className, count=0):       
    processed_classes = process_anchor(className, soup.find_all("a", {"class": className}), count) 
    print("Done extracting anchor {}".format(count))
    return processed_classes

def process_anchor(className, anchors, count=0):
    overall_data = {}
    for anchor in anchors:
        text, data = get_anchor_data(anchor) # Get anchor page number<str> and href value<str>
        if text == None and data == None:
            continue
        if count > 0 and text == str(count):
            overall_data[text] = data
        if count == 0:
            overall_data[text] = data
    print("OVERALL_DATA", overall_data)
    return overall_data

def get_anchor_data(anchor):
    anchor_text = anchor.get_text()
    if len(anchor_text) != 0 and anchor_text != "15":
        text = anchor.get_text()
        data = anchor.get("href")
        return text, data
    return None, None

# %%
class_name = "_833p2h"
anchor_data = extract_anchors(soup, class_name)
# Out:
# OVERALL_DATA {'2': '/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMCwidmVyc2lvbiI6MX0%3D', '3': '/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo0MCwidmVyc2lvbiI6MX0%3D', '4': '/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo2MCwidmVyc2lvbiI6MX0%3D'}
# Done extracting anchor 0

# %%
"""
Construct list of url objects containing url_obj
{page_num<int>: href<str>}

"""
def get_urls(anchor_data, urls):
    base_url = "https://www.airbnb.com"
    for key, value in anchor_data.items():
        url_obj = {}
        url_obj[key] = str(base_url + anchor_data[key]) 
        urls.append(url_obj)
    return urls

# %%
urls_list = [{1: "https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=september&flexible_trip_dates%5B%5D=october&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&adults=0&children=0&infants=0&pets=0&search_type=AUTOSUGGEST"}] 
# Get urls 1-4
urls = get_urls(anchor_data, urls_list)
urls
# Out:
# [{1: 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=september&flexible_trip_dates%5B%5D=october&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&adults=0&children=0&infants=0&pets=0&search_type=AUTOSUGGEST'},
#  {'2': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMCwidmVyc2lvbiI6MX0%3D'},
#  {'3': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo0MCwidmVyc2lvbiI6MX0%3D'},
#  {'4': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo2MCwidmVyc2lvbiI6MX0%3D'}]

# %%
# Custom function to get url pages 5-14
def get_remaining_urls(urls):
    count = 5
    class_name=  "_833p2h"
    url_data = [urls[-1]]
    while count <= 15:
        count_soup = extract_listing(url_data[-1])
        count_anchor = extract_anchors(count_soup, class_name, count)
        url_data = get_urls(count_anchor, url_data)
        count+=1
    return url_data

# %%
# Get Remaining urls 5-14
remaining_urls = get_remaining_urls(urls)
# Out:
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo2MCwidmVyc2lvbiI6MX0%3D--2022-12-04 00:23:31.661713
# OVERALL_DATA {'5': '/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo4MCwidmVyc2lvbiI6MX0%3D'}
# Done extracting anchor 5
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo4MCwidmVyc2lvbiI6MX0%3D--2022-12-04 00:23:33.448440
# OVERALL_DATA {'6': '/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxMDAsInZlcnNpb24iOjF9'}
# Done extracting anchor 6
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxMDAsInZlcnNpb24iOjF9--2022-12-04 00:23:35.346916
# OVERALL_DATA {'7': '/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxMjAsInZlcnNpb24iOjF9'}
# Done extracting anchor 7
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxMjAsInZlcnNpb24iOjF9--2022-12-04 00:23:37.258919
# OVERALL_DATA {'8': '/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxNDAsInZlcnNpb24iOjF9'}
# Done extracting anchor 8
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxNDAsInZlcnNpb24iOjF9--2022-12-04 00:23:38.759770
# OVERALL_DATA {'9': '/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxNjAsInZlcnNpb24iOjF9'}
# Done extracting anchor 9
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxNjAsInZlcnNpb24iOjF9--2022-12-04 00:23:40.446753
# OVERALL_DATA {'10': '/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxODAsInZlcnNpb24iOjF9'}
# Done extracting anchor 10
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxODAsInZlcnNpb24iOjF9--2022-12-04 00:23:42.056713
# OVERALL_DATA {'11': '/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMDAsInZlcnNpb24iOjF9'}
# Done extracting anchor 11
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMDAsInZlcnNpb24iOjF9--2022-12-04 00:23:43.560474
# OVERALL_DATA {'12': '/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMjAsInZlcnNpb24iOjF9'}
# Done extracting anchor 12
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMjAsInZlcnNpb24iOjF9--2022-12-04 00:23:45.552503
# OVERALL_DATA {'13': '/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyNDAsInZlcnNpb24iOjF9'}
# Done extracting anchor 13
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyNDAsInZlcnNpb24iOjF9--2022-12-04 00:23:47.255123
# OVERALL_DATA {'14': '/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyNjAsInZlcnNpb24iOjF9'}
# Done extracting anchor 14
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyNjAsInZlcnNpb24iOjF9--2022-12-04 00:23:48.759100
# OVERALL_DATA {}
# Done extracting anchor 15

# %%
# Create list of all urls 1-14
all_urls = urls + remaining_urls[1:]
all_urls
# Out:
# [{1: 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=september&flexible_trip_dates%5B%5D=october&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&adults=0&children=0&infants=0&pets=0&search_type=AUTOSUGGEST'},
#  {'2': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMCwidmVyc2lvbiI6MX0%3D'},
#  {'3': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo0MCwidmVyc2lvbiI6MX0%3D'},
#  {'4': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo2MCwidmVyc2lvbiI6MX0%3D'},
#  {'5': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo4MCwidmVyc2lvbiI6MX0%3D'},
#  {'6': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxMDAsInZlcnNpb24iOjF9'},
#  {'7': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxMjAsInZlcnNpb24iOjF9'},
#  {'8': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxNDAsInZlcnNpb24iOjF9'},
#  {'9': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxNjAsInZlcnNpb24iOjF9'},
#  {'10': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxODAsInZlcnNpb24iOjF9'},
#  {'11': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMDAsInZlcnNpb24iOjF9'},
#  {'12': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMjAsInZlcnNpb24iOjF9'},
#  {'13': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyNDAsInZlcnNpb24iOjF9'},
#  {'14': 'https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyNjAsInZlcnNpb24iOjF9'}]

# %%
# Extract soup objects and query for div that has listing data
listing_pages = [extract_listing(urlObj).find_all("div", {"class": "g1qv1ctd cb4nyux dir dir-ltr"}) for urlObj in all_urls]
# Out:
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=september&flexible_trip_dates%5B%5D=october&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&adults=0&children=0&infants=0&pets=0&search_type=AUTOSUGGEST--2022-12-04 00:23:50.654835
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMCwidmVyc2lvbiI6MX0%3D--2022-12-04 00:23:52.656152
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo0MCwidmVyc2lvbiI6MX0%3D--2022-12-04 00:23:54.259902
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo2MCwidmVyc2lvbiI6MX0%3D--2022-12-04 00:23:56.162706
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo4MCwidmVyc2lvbiI6MX0%3D--2022-12-04 00:23:57.952351
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxMDAsInZlcnNpb24iOjF9--2022-12-04 00:23:59.661280
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxMjAsInZlcnNpb24iOjF9--2022-12-04 00:24:01.858532
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxNDAsInZlcnNpb24iOjF9--2022-12-04 00:24:03.553734
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxNjAsInZlcnNpb24iOjF9--2022-12-04 00:24:05.246268
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxODAsInZlcnNpb24iOjF9--2022-12-04 00:24:06.757198
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMDAsInZlcnNpb24iOjF9--2022-12-04 00:24:08.358171
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyMjAsInZlcnNpb24iOjF9--2022-12-04 00:24:10.853019
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyNDAsInZlcnNpb24iOjF9--2022-12-04 00:24:12.557863
# Extracted Data: https://www.airbnb.com/s/New-York/homes?place_id=ChIJOwg_06VPwokRYv534QaPC8g&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=august&flexible_trip_dates%5B%5D=december&flexible_trip_dates%5B%5D=february&flexible_trip_dates%5B%5D=january&flexible_trip_dates%5B%5D=july&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=march&flexible_trip_dates%5B%5D=may&flexible_trip_dates%5B%5D=november&flexible_trip_dates%5B%5D=october&flexible_trip_dates%5B%5D=september&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=AUTOSUGGEST&tab_id=home_tab&query=New%20York&price_filter_input_type=0&price_filter_num_nights=2&federated_search_session_id=b00169f9-041f-494c-8c12-430c4049d4f0&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoyNjAsInZlcnNpb24iOjF9--2022-12-04 00:24:14.239728

# %%
# Returns object for all data where key=column_name, value=column_row_value
def get_df_data(listing_pages):
    a = []
    b = []
    c = []
    d = []
    e = []
    f = []
    for listings in listing_pages:
    # Containers used to store div data, clear for each listing
        for listing in listings:
            listing_data = extract_listing_data(listing) # Use helper func to map soup -> obj
            print("listing_data", listing_data)
            if listing_data == None:
                continue
            a.append(listing_data["title"])
            b.append(listing_data["description"])
            c.append(listing_data["num_bed"])
            d.append(listing_data["price_val"])
            e.append(listing_data["price_per_night"])
            f.append(listing_data["average_rating_num_rating"])
    df_data = {
        "title": a,
        "description": b,
        "num_beds": c ,
        "price_val": d ,
        "price_per_night": e,
        "average_rating_num_rating": f
    }
    return df_data

# Helper function for mapping soup data to obj for row data
def extract_listing_data(listing):
    listing_data = {}
    if listing.find("span", {"class": "_tyxjp1"}) == None:
        return None
    listing_data["title"] = listing.find("div", {"class": "t1jojoys dir dir-ltr"}).contents[0] # title
    listing_data["description"] = listing.find("span", {"class": "t6mzqp7 dir dir-ltr"}).contents[0] # Span description
    listing_data["num_bed"] = listing.find("span", {"class": "dir dir-ltr"}).contents[0] # div num beds
    listing_data["price_val"] = listing.find("span", {"class": "_tyxjp1"}).contents[0] # price_val
    price_per_night_data = listing.find("span", {"class": "a8jt5op dir dir-ltr"}).contents[0] # price per night
    listing_data["price_per_night"] = " ".join(str(s) for s in price_per_night_data)
    listing_data["average_rating_num_rating"] = listing.find("span", {"class": "r1dxllyb dir dir-ltr"}).contents[0] if listing.find("span", {"class": "r1dxllyb dir dir-ltr"}) else "NONE"  # Average rating and num of ratings
    return listing_data

# %%
# Extract all the data from the listing pages
df_data = get_df_data(listing_pages)
# Out:
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'spacious chelsea room', 'num_bed': '1 double bed', 'price_val': '$77', 'price_per_night': '$ 7 7   p e r   n i g h t', 'average_rating_num_rating': '4.91 (98)'}
# listing_data {'title': 'Private room in New York', 'description': 'Minimal room 4 SofaBed + loft bed in Manhattan', 'num_bed': '2 beds', 'price_val': '$79', 'price_per_night': '$ 7 9   p e r   n i g h t', 'average_rating_num_rating': '4.44 (117)'}
# listing_data {'title': 'Private room in New York City', 'description': 'Comfortable and clean bedroom', 'num_bed': '1 double bed', 'price_val': '$65', 'price_per_night': '$ 6 5   p e r   n i g h t', 'average_rating_num_rating': '4.84 (151)'}
# listing_data {'title': 'Private room in New York City', 'description': "Cozy, quiet room in artist's apartment", 'num_bed': '1 single bed', 'price_val': '$49', 'price_per_night': '$ 4 9   p e r   n i g h t', 'average_rating_num_rating': '4.78 (120)'}
# listing_data None
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': '[Manhattan Heart] 800m to Time Square/Broadway', 'num_bed': '1 bed', 'price_val': '$126', 'price_per_night': '$ 1 2 6   p e r   n i g h t', 'average_rating_num_rating': '4.91 (23)'}
# listing_data {'title': 'Condo in New York', 'description': 'Upper West Side', 'num_bed': '2 beds', 'price_val': '$143', 'price_per_night': '$ 1 4 3   p e r   n i g h t', 'average_rating_num_rating': '5.0 (4)'}
# listing_data None
# listing_data {'title': 'Apartment in New York City', 'description': 'Amazing &Artsy PRIME location!Entire unit.', 'num_bed': '2 beds', 'price_val': '$105', 'price_per_night': '$ 1 0 5   p e r   n i g h t', 'average_rating_num_rating': '4.85 (92)'}
# listing_data {'title': 'Hotel room in New York', 'description': 'FREE BREAKFAST! SPACIOUS ROOM in Times Square', 'num_bed': '1 bed', 'price_val': '$226', 'price_per_night': '$ 2 2 6   p e r   n i g h t', 'average_rating_num_rating': '4.48 (188)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Big Room w/ private entrance and Private Bathroom.', 'num_bed': '1 queen bed', 'price_val': '$98', 'price_per_night': '$ 9 8   p e r   n i g h t', 'average_rating_num_rating': '4.89 (81)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Cozy Studio in Gramercy park', 'num_bed': '1 double bed', 'price_val': '$92', 'price_per_night': '$ 9 2   p e r   n i g h t', 'average_rating_num_rating': '4.65 (122)'}
# listing_data None
# listing_data {'title': 'Apartment in New York', 'description': 'Upper West - Chic Studio', 'num_bed': '1 bed', 'price_val': '$101', 'price_per_night': '$ 1 0 1   p e r   n i g h t', 'average_rating_num_rating': '4.74 (23)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Simple New York Escape.', 'num_bed': '1 double bed', 'price_val': '$75', 'price_per_night': '$ 7 5   p e r   n i g h t', 'average_rating_num_rating': '4.92 (24)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Gramercy park Apartment (2beds)', 'num_bed': '2 beds', 'price_val': '$99', 'price_per_night': '$ 9 9   p e r   n i g h t', 'average_rating_num_rating': '4.53 (113)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Gramercy park Apartment (2beds)', 'num_bed': '2 beds', 'price_val': '$99', 'price_per_night': '$ 9 9   p e r   n i g h t', 'average_rating_num_rating': '4.53 (113)'}
# listing_data None
# listing_data {'title': 'Private room in New York City', 'description': "Charming, sunny room in artist's apartment", 'num_bed': '1 single bed', 'price_val': '$56', 'price_per_night': '$ 5 6   p e r   n i g h t', 'average_rating_num_rating': '4.8 (155)'}
# listing_data {'title': 'Private room in New York', 'description': 'Simple New York Escape.', 'num_bed': '1 double bed', 'price_val': '$75', 'price_per_night': '$ 7 5   p e r   n i g h t', 'average_rating_num_rating': '4.92 (24)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Tranquility Suite: Upper West Side (UWS) 1 Bedroom', 'num_bed': '1 bed', 'price_val': '$125', 'price_per_night': '$ 1 2 5   p e r   n i g h t', 'average_rating_num_rating': '4.92 (52)'}
# listing_data {'title': 'Private room in New York', 'description': "Large Furnished Room Near B'way\u3000", 'num_bed': '1 queen bed', 'price_val': '$68', 'price_per_night': '$ 6 8   p e r   n i g h t', 'average_rating_num_rating': '4.23 (558)'}
# listing_data {'title': 'Private room in New York', 'description': '[Manhattan Heart] 0.5 mile to Time Square/Broadway', 'num_bed': '1 king bed', 'price_val': '$143', 'price_per_night': '$ 1 4 3   p e r   n i g h t', 'average_rating_num_rating': '4.62 (21)'}
# listing_data {'title': 'Private room in New York City', 'description': 'An Oasis in the Heart of Williamsburg, BK', 'num_bed': '1 double bed', 'price_val': '$55', 'price_per_night': '$ 5 5   p e r   n i g h t', 'average_rating_num_rating': '4.88 (40)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'East Village Charm', 'num_bed': '1 bed', 'price_val': '$85', 'price_per_night': '$ 8 5   p e r   n i g h t', 'average_rating_num_rating': '4.84 (226)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Guest Room with 1 King Bed at Holiday Inn New York City Wall Street', 'num_bed': '1 king bed', 'price_val': '$129', 'price_per_night': '$ 1 2 9   p e r   n i g h t', 'average_rating_num_rating': '4.43 (7)'}
# listing_data {'title': 'Guest suite in New York City', 'description': 'An entire clean private studio in New York', 'num_bed': '1 double bed', 'price_val': '$49', 'price_per_night': '$ 4 9   p e r   n i g h t', 'average_rating_num_rating': '4.86 (259)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Studio with 1 Queen Bed at Candlewood Suites Times Square', 'num_bed': '1 queen bed', 'price_val': '$109', 'price_per_night': '$ 1 0 9   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Apartment in New York', 'description': 'Authentic Living in Manhattan', 'num_bed': '1 queen bed', 'price_val': '$115', 'price_per_night': '$ 1 1 5   p e r   n i g h t', 'average_rating_num_rating': '4.79 (201)'}
# listing_data None
# listing_data None
# listing_data {'title': 'Apartment in New York', 'description': 'Steps From Times Square and all transportation', 'num_bed': '2 beds', 'price_val': '$155', 'price_per_night': '$ 1 5 5   p e r   n i g h t', 'average_rating_num_rating': '4.25 (12)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': '20 minutes Laguardia Airport 10 mins Midtown', 'num_bed': '1 bed', 'price_val': '$55', 'price_per_night': '$ 5 5   p e r   n i g h t', 'average_rating_num_rating': '4.79 (57)'}
# listing_data {'title': 'Private room in New York', 'description': 'Big Room w/ private entrance and Private Bathroom.', 'num_bed': '1 queen bed', 'price_val': '$98', 'price_per_night': '$ 9 8   p e r   n i g h t', 'average_rating_num_rating': '4.89 (81)'}
# listing_data {'title': 'Private room in New York', 'description': 'Warm, cozy room in the heart of the East Village', 'num_bed': '1 single bed', 'price_val': '$100', 'price_per_night': '$ 1 0 0   p e r   n i g h t', 'average_rating_num_rating': '4.93 (74)'}
# listing_data {'title': 'Private room in New York', 'description': 'Private Bedroom, Manhattan, 70s, Upper East Side', 'num_bed': '1 double bed', 'price_val': '$79', 'price_per_night': '$ 7 9   p e r   n i g h t', 'average_rating_num_rating': '4.87 (52)'}
# listing_data {'title': 'Private room in New York', 'description': 'Minimal room 2 Bunk bed in Manhattan', 'num_bed': '2 beds', 'price_val': '$68', 'price_per_night': '$ 6 8   p e r   n i g h t', 'average_rating_num_rating': '4.47 (162)'}
# listing_data {'title': 'Private room in New York', 'description': 'Harlem luxury w/ great amenities!', 'num_bed': '1 queen bed', 'price_val': '$65', 'price_per_night': '$ 6 5   p e r   n i g h t', 'average_rating_num_rating': '4.89 (166)'}
# listing_data None
# listing_data {'title': 'Apartment in New York', 'description': 'Tranquility Suite: Upper West Side (UWS) 1 Bedroom', 'num_bed': '1 bed', 'price_val': '$125', 'price_per_night': '$ 1 2 5   p e r   n i g h t', 'average_rating_num_rating': '4.92 (52)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Beautiful Private Room in NYC R-3Min Walk to Metro', 'num_bed': '1 queen bed', 'price_val': '$53', 'price_per_night': '$ 5 3   p e r   n i g h t', 'average_rating_num_rating': '5.0 (11)'}
# listing_data {'title': 'Hotel room in New York', 'description': 'FREE BREAKFAST! SPACIOUS ROOM in Times Square', 'num_bed': '1 bed', 'price_val': '$226', 'price_per_night': '$ 2 2 6   p e r   n i g h t', 'average_rating_num_rating': '4.48 (188)'}
# listing_data {'title': 'Private room in New York', 'description': 'Uptown Modern Twist in Harlem', 'num_bed': '2 beds', 'price_val': '$68', 'price_per_night': '$ 6 8   p e r   n i g h t', 'average_rating_num_rating': '4.84 (210)'}
# listing_data {'title': 'Private room in New York', 'description': '20 minutes Laguardia Airport 10 mins Midtown', 'num_bed': '1 bed', 'price_val': '$55', 'price_per_night': '$ 5 5   p e r   n i g h t', 'average_rating_num_rating': '4.79 (57)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Private room with shower on Union Square side 3', 'num_bed': '2 beds', 'price_val': '$83', 'price_per_night': '$ 8 3   p e r   n i g h t', 'average_rating_num_rating': '4.61 (59)'}
# listing_data {'title': 'Private room in Brooklyn', 'description': 'Private bedroom & bath in Red Hook Bklyn for solo', 'num_bed': '1 single bed', 'price_val': '$60', 'price_per_night': '$ 6 0   p e r   n i g h t', 'average_rating_num_rating': '4.85 (338)'}
# listing_data {'title': 'Private room in New York', 'description': 'Cozy room at LOWER EAST SIDE', 'num_bed': '1 bed', 'price_val': '$88', 'price_per_night': '$ 8 8   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Comfortable Room Gramercy (female only, see descr)', 'num_bed': '1 double bed', 'price_val': '$72', 'price_per_night': '$ 7 2   p e r   n i g h t', 'average_rating_num_rating': '4.97 (112)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Steps From Times Square and all transportation', 'num_bed': '2 beds', 'price_val': '$155', 'price_per_night': '$ 1 5 5   p e r   n i g h t', 'average_rating_num_rating': '4.25 (12)'}
# listing_data {'title': 'Private room in New York', 'description': 'Comfort and Charm in Harlem Brownstone near Subway', 'num_bed': '1 queen bed', 'price_val': '$92', 'price_per_night': '$ 9 2   p e r   n i g h t', 'average_rating_num_rating': '4.97 (191)'}
# listing_data {'title': 'Private room in New York', 'description': 'Sunny Beach House type room on UWS', 'num_bed': '1 double bed', 'price_val': '$95', 'price_per_night': '$ 9 5   p e r   n i g h t', 'average_rating_num_rating': '4.84 (276)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Gramercy park Apartment (2beds)', 'num_bed': '2 beds', 'price_val': '$99', 'price_per_night': '$ 9 9   p e r   n i g h t', 'average_rating_num_rating': '4.53 (113)'}
# listing_data {'title': 'Private room in New York', 'description': 'Cozy room at LOWER EAST SIDE', 'num_bed': '1 bed', 'price_val': '$88', 'price_per_night': '$ 8 8   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Shared room in New York', 'description': 'Charming & Affordable Shared Studio  in WestHarlem', 'num_bed': '1 single bed', 'price_val': '$34', 'price_per_night': '$ 3 4   p e r   n i g h t', 'average_rating_num_rating': '4.62 (146)'}
# listing_data None
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Minimal room 3 SofaBed + loft bed in Manhattan', 'num_bed': '2 beds', 'price_val': '$79', 'price_per_night': '$ 7 9   p e r   n i g h t', 'average_rating_num_rating': '4.63 (75)'}
# listing_data {'title': 'Private room in New York', 'description': 'Cozy Chelsea Apt Great Location', 'num_bed': '1 single bed', 'price_val': '$98', 'price_per_night': '$ 9 8   p e r   n i g h t', 'average_rating_num_rating': '4.76 (123)'}
# listing_data {'title': 'Apartment in West New York', 'description': 'Stunning 3 Bedroom Home minutes away from NYC', 'num_bed': '4 beds', 'price_val': '$89', 'price_per_night': '$ 8 9   p e r   n i g h t', 'average_rating_num_rating': '4.51 (300)'}
# listing_data {'title': 'Private room in New York', 'description': 'Individual Cubicle Room in NYC/Mixed Floor', 'num_bed': '1 bed', 'price_val': '$122', 'price_per_night': '$ 1 2 2   p e r   n i g h t', 'average_rating_num_rating': '4.58 (110)'}
# listing_data {'title': 'Private room in New York', 'description': 'Cozy Room in Central Park Area!!', 'num_bed': '1 bed', 'price_val': '$67', 'price_per_night': '$ 6 7   p e r   n i g h t', 'average_rating_num_rating': '3.81 (57)'}
# listing_data {'title': 'Private room in New York', 'description': 'Big Room w/ private entrance and Private Bathroom.', 'num_bed': '1 queen bed', 'price_val': '$98', 'price_per_night': '$ 9 8   p e r   n i g h t', 'average_rating_num_rating': '4.89 (81)'}
# listing_data {'title': 'Private room in New York', 'description': 'Charming Midtown Bedroom Manhattan', 'num_bed': '1 bed', 'price_val': '$115', 'price_per_night': '$ 1 1 5   p e r   n i g h t', 'average_rating_num_rating': '4.88 (17)'}
# listing_data None
# listing_data {'title': 'Private room in Brooklyn', 'description': 'Private Room Near Major Transportation', 'num_bed': '1 bed', 'price_val': '$53', 'price_per_night': '$ 5 3   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Private room in New York', 'description': 'Hidden Gem: Bedroom and Bath in Midtown Duplex', 'num_bed': '2 beds', 'price_val': '$95', 'price_per_night': '$ 9 5   p e r   n i g h t', 'average_rating_num_rating': '4.65 (43)'}
# listing_data {'title': 'Loft in New York', 'description': 'Lovely studio 5 minutes away from Lga airport.', 'num_bed': '1 queen bed', 'price_val': '$100', 'price_per_night': '$ 1 0 0   p e r   n i g h t', 'average_rating_num_rating': '4.97 (62)'}
# listing_data {'title': 'Private room in New York', 'description': 'Art-filled peaceful & private room at Zen Bodega', 'num_bed': '1 bed', 'price_val': '$75', 'price_per_night': '$ 7 5   p e r   n i g h t', 'average_rating_num_rating': '4.83 (6)'}
# listing_data {'title': 'Apartment in Brooklyn', 'description': 'Prime studio gem in front of Fort Greene Park', 'num_bed': '1 king bed', 'price_val': '$192', 'price_per_night': '$ 1 9 2   p e r   n i g h t', 'average_rating_num_rating': '4.88 (26)'}
# listing_data {'title': 'Apartment in New York', 'description': '✨COZY MODERN STUDIO near JFK airport', 'num_bed': '1 queen bed', 'price_val': '$96', 'price_per_night': '$ 9 6   p e r   n i g h t', 'average_rating_num_rating': '5.0 (64)'}
# listing_data {'title': 'Private room in New York', 'description': 'Private Room in Manhattan 15 min. from Midtown!', 'num_bed': '1 single bed', 'price_val': '$99', 'price_per_night': '$ 9 9   p e r   n i g h t', 'average_rating_num_rating': '4.92 (184)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Adorable one bedroom in upper east side', 'num_bed': '1 bed', 'price_val': '$135', 'price_per_night': '$ 1 3 5   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Comfortable Room Gramercy (female only, see descr)', 'num_bed': '1 double bed', 'price_val': '$72', 'price_per_night': '$ 7 2   p e r   n i g h t', 'average_rating_num_rating': '4.97 (112)'}
# listing_data None
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Charming Midtown Bedroom Manhattan', 'num_bed': '1 bed', 'price_val': '$115', 'price_per_night': '$ 1 1 5   p e r   n i g h t', 'average_rating_num_rating': '4.88 (17)'}
# listing_data None
# listing_data None
# listing_data {'title': 'Apartment in New York', 'description': 'Studio Artitaje in Harlem', 'num_bed': '2 beds', 'price_val': '$93', 'price_per_night': '$ 9 3   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Private room in New York', 'description': 'Cozy Room in Downtown Near Subway St -5 Min Walk', 'num_bed': '1 bed', 'price_val': '$95', 'price_per_night': '$ 9 5   p e r   n i g h t', 'average_rating_num_rating': '4.25 (4)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Hell’s Kitchen 1BR Holiday Deal!', 'num_bed': '1 bed', 'price_val': '$143', 'price_per_night': '$ 1 4 3   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Cozy Room in Central Park Area!!', 'num_bed': '1 bed', 'price_val': '$67', 'price_per_night': '$ 6 7   p e r   n i g h t', 'average_rating_num_rating': '3.81 (57)'}
# listing_data None
# listing_data {'title': 'Apartment in Brooklyn', 'description': 'Walk-in 1 BR Apt in Bay Ridge 86st, Close to all', 'num_bed': '2 beds', 'price_val': '$89', 'price_per_night': '$ 8 9   p e r   n i g h t', 'average_rating_num_rating': '4.94 (34)'}
# listing_data {'title': 'Apartment in New York', 'description': 'NYC Style Superior Family Studio', 'num_bed': '3 double beds', 'price_val': '$214', 'price_per_night': '$ 2 1 4   p e r   n i g h t', 'average_rating_num_rating': '4.81 (450)'}
# listing_data {'title': 'Apartment in Brooklyn', 'description': 'Lovely Studio apartment- Modern & Bright', 'num_bed': '1 queen bed', 'price_val': '$105', 'price_per_night': '$ 1 0 5   p e r   n i g h t', 'average_rating_num_rating': '5.0 (3)'}
# listing_data {'title': 'Vacation home in New York', 'description': 'Chic Studio Apartment in the Heart of Queens', 'num_bed': '1 queen bed', 'price_val': '$86', 'price_per_night': '$ 8 6   p e r   n i g h t', 'average_rating_num_rating': '4.86 (7)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Delightful, Bright and Comfortable Bedroom', 'num_bed': '1 queen bed', 'price_val': '$99', 'price_per_night': '$ 9 9   p e r   n i g h t', 'average_rating_num_rating': '4.93 (46)'}
# listing_data {'title': 'Shared room in New York', 'description': 'Charming & Affordable Shared Studio  in WestHarlem', 'num_bed': '1 single bed', 'price_val': '$34', 'price_per_night': '$ 3 4   p e r   n i g h t', 'average_rating_num_rating': '4.62 (146)'}
# listing_data {'title': 'Private room in New York City', 'description': 'Cozy Brooklyn Hideaway', 'num_bed': '1 queen bed', 'price_val': '$73', 'price_per_night': '$ 7 3   p e r   n i g h t', 'average_rating_num_rating': '4.88 (25)'}
# listing_data {'title': 'Private room in New York', 'description': 'Hidden Gem: Bedroom and Bath in Midtown Duplex', 'num_bed': '2 beds', 'price_val': '$95', 'price_per_night': '$ 9 5   p e r   n i g h t', 'average_rating_num_rating': '4.65 (43)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Views in Heart of Manhattan', 'num_bed': '2 beds', 'price_val': '$220', 'price_per_night': '$ 2 2 0   p e r   n i g h t', 'average_rating_num_rating': '5.0 (3)'}
# listing_data {'title': 'Private room in New York', 'description': 'Big Private Room in Little Italy/Chinatown NYC', 'num_bed': '1 queen bed', 'price_val': '$102', 'price_per_night': '$ 1 0 2   p e r   n i g h t', 'average_rating_num_rating': '4.93 (167)'}
# listing_data {'title': 'Private room in New York City', 'description': 'Private Room Near Major Transportation', 'num_bed': '1 bed', 'price_val': '$53', 'price_per_night': '$ 5 3   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data None
# listing_data None
# listing_data {'title': 'Apartment in New York', 'description': 'Cozy Studio in the Heart of Midtown Manhattan!', 'num_bed': '1 bed', 'price_val': '$171', 'price_per_night': '$ 1 7 1   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data None
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Central Park Bedroom at Norms', 'num_bed': '1 bed', 'price_val': '$119', 'price_per_night': '$ 1 1 9   p e r   n i g h t', 'average_rating_num_rating': '4.71 (63)'}
# listing_data None
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Private Room in Manhattan 15 min. from Midtown!', 'num_bed': '1 single bed', 'price_val': '$99', 'price_per_night': '$ 9 9   p e r   n i g h t', 'average_rating_num_rating': '4.92 (184)'}
# listing_data {'title': 'Private room in New York', 'description': 'Individual Cubicle Room in NYC/Boys Floor', 'num_bed': '1 single bed', 'price_val': '$122', 'price_per_night': '$ 1 2 2   p e r   n i g h t', 'average_rating_num_rating': '4.42 (502)'}
# listing_data {'title': 'Private room in New York', 'description': 'Private room with Shared bath on Union Square 1', 'num_bed': '2 beds', 'price_val': '$97', 'price_per_night': '$ 9 7   p e r   n i g h t', 'average_rating_num_rating': '4.43 (53)'}
# listing_data {'title': 'Apartment in New York', 'description': '☆ STUDIO East Village ☆ Own bath! ☆ Sleeps 5', 'num_bed': '6 beds', 'price_val': '$168', 'price_per_night': '$ 1 6 8   p e r   n i g h t', 'average_rating_num_rating': '4.12 (426)'}
# listing_data {'title': 'Private room in New York City', 'description': 'Cozy Private Room in Ridgewood', 'num_bed': '1 bed', 'price_val': '$51', 'price_per_night': '$ 5 1   p e r   n i g h t', 'average_rating_num_rating': '4.6 (5)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Kingsize bedroom in Harlem brownstone', 'num_bed': '1 king bed', 'price_val': '$117', 'price_per_night': '$ 1 1 7   p e r   n i g h t', 'average_rating_num_rating': '4.88 (293)'}
# listing_data {'title': 'Private room in New York', 'description': 'Minimal room 6 SofaBed + loft bed in Manhattan', 'num_bed': '2 beds', 'price_val': '$68', 'price_per_night': '$ 6 8   p e r   n i g h t', 'average_rating_num_rating': '4.6 (47)'}
# listing_data {'title': 'Townhouse in New York City', 'description': 'Sun filled 2BR in BedStuy Townhouse', 'num_bed': '3 beds', 'price_val': '$175', 'price_per_night': '$ 1 7 5   p e r   n i g h t', 'average_rating_num_rating': '4.78 (450)'}
# listing_data None
# listing_data {'title': 'Apartment in Weehawken', 'description': 'Luxe 1-Bedroom Flat Near Manhattan', 'num_bed': '1 double bed', 'price_val': '$100', 'price_per_night': '$ 1 0 0   p e r   n i g h t', 'average_rating_num_rating': '4.84 (439)'}
# listing_data {'title': 'Guest suite in New York City', 'description': 'Private, Cozy Suite by Stella Smoke/Drug free', 'num_bed': '1 queen bed', 'price_val': '$58', 'price_per_night': '$ 5 8   p e r   n i g h t', 'average_rating_num_rating': '4.84 (94)'}
# listing_data {'title': 'Private room in New York', 'description': 'Private Room in Manhattan 15 min. from Midtown!', 'num_bed': '1 single bed', 'price_val': '$99', 'price_per_night': '$ 9 9   p e r   n i g h t', 'average_rating_num_rating': '4.92 (184)'}
# listing_data {'title': 'Private room in New York City', 'description': 'Great location private bedroom in Queens', 'num_bed': '1 queen bed', 'price_val': '$55', 'price_per_night': '$ 5 5   p e r   n i g h t', 'average_rating_num_rating': '4.51 (43)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Hidden Gem: Bedroom and Bath in Midtown Duplex', 'num_bed': '2 beds', 'price_val': '$95', 'price_per_night': '$ 9 5   p e r   n i g h t', 'average_rating_num_rating': '4.65 (43)'}
# listing_data {'title': 'Condo in West New York', 'description': '✴️ Cozy, Affordable & Minutes 2 Times Square', 'num_bed': '2 beds', 'price_val': '$87', 'price_per_night': '$ 8 7   p e r   n i g h t', 'average_rating_num_rating': '4.63 (304)'}
# listing_data {'title': 'Private room in New York', 'description': 'Shared APT private room 1 Midtown', 'num_bed': '1 bunk bed', 'price_val': '$77', 'price_per_night': '$ 7 7   p e r   n i g h t', 'average_rating_num_rating': '4.79 (150)'}
# listing_data {'title': 'Private room in New York', 'description': 'Comfy Spacious BR very close to Times Square', 'num_bed': '1 queen bed', 'price_val': '$89', 'price_per_night': '$ 8 9   p e r   n i g h t', 'average_rating_num_rating': '4.78 (138)'}
# listing_data {'title': 'Private room in New York', 'description': 'Private room with Shared bath on Union Square 5', 'num_bed': '2 beds', 'price_val': '$69', 'price_per_night': '$ 6 9   p e r   n i g h t', 'average_rating_num_rating': '4.26 (19)'}
# listing_data {'title': 'Private room in New York', 'description': "New Chic Designer's Bedroom", 'num_bed': '1 double bed', 'price_val': '$95', 'price_per_night': '$ 9 5   p e r   n i g h t', 'average_rating_num_rating': '4.62 (231)'}
# listing_data {'title': 'Private room in New York', 'description': 'Cozy Room in Central Park Area!!', 'num_bed': '1 bed', 'price_val': '$67', 'price_per_night': '$ 6 7   p e r   n i g h t', 'average_rating_num_rating': '3.81 (57)'}
# listing_data {'title': 'Private room in New York', 'description': 'Delightful, Bright and Comfortable Bedroom', 'num_bed': '1 queen bed', 'price_val': '$99', 'price_per_night': '$ 9 9   p e r   n i g h t', 'average_rating_num_rating': '4.93 (46)'}
# listing_data None
# listing_data {'title': 'Apartment in New York City', 'description': 'Two Bedroom Apartment in Sunset Park - Brooklyn', 'num_bed': '3 beds', 'price_val': '$95', 'price_per_night': '$ 9 5   p e r   n i g h t', 'average_rating_num_rating': '4.8 (136)'}
# listing_data {'title': 'Condo in New York', 'description': 'Bright artist studio 8 min walk from central park', 'num_bed': '1 queen bed', 'price_val': '$154', 'price_per_night': '$ 1 5 4   p e r   n i g h t', 'average_rating_num_rating': '5.0 (7)'}
# listing_data None
# listing_data None
# listing_data None
# listing_data {'title': 'Apartment in New York City', 'description': 'Cosy one-bedroom nest in the heart of Williamsburg', 'num_bed': '1 queen bed', 'price_val': '$165', 'price_per_night': '$ 1 6 5   p e r   n i g h t', 'average_rating_num_rating': '4.68 (179)'}
# listing_data None
# listing_data {'title': 'Townhouse in New York City', 'description': 'Sun filled 2BR in BedStuy Townhouse', 'num_bed': '3 beds', 'price_val': '$175', 'price_per_night': '$ 1 7 5   p e r   n i g h t', 'average_rating_num_rating': '4.78 (450)'}
# listing_data {'title': 'Private room in New York City', 'description': 'Comfortable and clean bedroom', 'num_bed': '1 double bed', 'price_val': '$65', 'price_per_night': '$ 6 5   p e r   n i g h t', 'average_rating_num_rating': '4.84 (151)'}
# listing_data None
# listing_data {'title': 'Hotel room in New York', 'description': 'Luxury City Suites Steps from Central Park', 'num_bed': '2 beds', 'price_val': '$233', 'price_per_night': '$ 2 3 3   p e r   n i g h t', 'average_rating_num_rating': '4.53 (166)'}
# listing_data {'title': 'Apartment in New York', 'description': 'A Upper East Side Flat with a Home Office', 'num_bed': '1 bed', 'price_val': '$140', 'price_per_night': '$ 1 4 0   p e r   n i g h t', 'average_rating_num_rating': 'NONE'}
# listing_data {'title': 'Apartment in New York', 'description': 'Brand New Alcove Studio right by One World Trade', 'num_bed': '1 bed', 'price_val': '$200', 'price_per_night': '$ 2 0 0   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Apartment in New York', 'description': 'THE SMALL CHATEAU IN THE TREES', 'num_bed': '2 beds', 'price_val': '$225', 'price_per_night': '$ 2 2 5   p e r   n i g h t', 'average_rating_num_rating': '4.84 (428)'}
# listing_data {'title': 'Vacation home in New York', 'description': 'Lovely studio in Manhattan', 'num_bed': '1 queen bed', 'price_val': '$140', 'price_per_night': '$ 1 4 0   p e r   n i g h t', 'average_rating_num_rating': '4.73 (15)'}
# listing_data {'title': 'Condo in New York', 'description': 'Bright artist studio 8 min walk from central park', 'num_bed': '1 queen bed', 'price_val': '$154', 'price_per_night': '$ 1 5 4   p e r   n i g h t', 'average_rating_num_rating': '5.0 (7)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Charming 1-Bed in the heart of NYC', 'num_bed': '1 bed', 'price_val': '$195', 'price_per_night': '$ 1 9 5   p e r   n i g h t', 'average_rating_num_rating': '4.55 (22)'}
# listing_data {'title': 'Apartment in Weehawken', 'description': 'Luxe 1-Bedroom Loft Near Manhattan', 'num_bed': '2 beds', 'price_val': '$100', 'price_per_night': '$ 1 0 0   p e r   n i g h t', 'average_rating_num_rating': '4.84 (359)'}
# listing_data {'title': 'Private room in New York', 'description': 'Comfort and Charm in Harlem Brownstone near Subway', 'num_bed': '1 queen bed', 'price_val': '$92', 'price_per_night': '$ 9 2   p e r   n i g h t', 'average_rating_num_rating': '4.97 (191)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Perfectly Located Private Room By Central Park', 'num_bed': '1 queen bed', 'price_val': '$115', 'price_per_night': '$ 1 1 5   p e r   n i g h t', 'average_rating_num_rating': '4.63 (56)'}
# listing_data {'title': 'Apartment in West New York', 'description': 'Stunning 3 Bedroom Home minutes away from NYC', 'num_bed': '4 beds', 'price_val': '$89', 'price_per_night': '$ 8 9   p e r   n i g h t', 'average_rating_num_rating': '4.51 (300)'}
# listing_data {'title': 'Home in New York', 'description': '2 Bedroom (Free-Parking)', 'num_bed': '3 beds', 'price_val': '$65', 'price_per_night': '$ 6 5   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Condo in New York', 'description': 'Bright artist studio 8 min walk from central park', 'num_bed': '1 queen bed', 'price_val': '$154', 'price_per_night': '$ 1 5 4   p e r   n i g h t', 'average_rating_num_rating': '5.0 (7)'}
# listing_data {'title': 'Private room in Jersey City', 'description': 'Suite w/Magnificent City View Quiet High Floor', 'num_bed': '1 bed', 'price_val': '$99', 'price_per_night': '$ 9 9   p e r   n i g h t', 'average_rating_num_rating': '5.0 (20)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': '“TIME SQUARE”42nd St. Private Single Bedroom Room.', 'num_bed': '1 bed', 'price_val': '$125', 'price_per_night': '$ 1 2 5   p e r   n i g h t', 'average_rating_num_rating': '4.09 (74)'}
# listing_data {'title': 'Hotel room in New York', 'description': 'Luxury City Suites Steps from Central Park', 'num_bed': '2 beds', 'price_val': '$233', 'price_per_night': '$ 2 3 3   p e r   n i g h t', 'average_rating_num_rating': '4.53 (166)'}
# listing_data {'title': 'Apartment in Brooklyn', 'description': 'Cozy 2 Bedroom Apt in Brooklyn', 'num_bed': '2 beds', 'price_val': '$185', 'price_per_night': '$ 1 8 5   p e r   n i g h t', 'average_rating_num_rating': '5.0 (33)'}
# listing_data {'title': 'Shared room in New York', 'description': 'Manhattan cute sofa bed', 'num_bed': '1 sofa bed', 'price_val': '$90', 'price_per_night': '$ 9 0   p e r   n i g h t', 'average_rating_num_rating': '4.74 (78)'}
# listing_data {'title': 'Private room in Brooklyn', 'description': 'Cozy and Sunny Private Room in Central Brooklyn', 'num_bed': '1 bed', 'price_val': '$74', 'price_per_night': '$ 7 4   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Private room in New York', 'description': 'Amazing Private Room @Madison Square Garden', 'num_bed': '1 queen bed', 'price_val': '$139', 'price_per_night': '$ 1 3 9   p e r   n i g h t', 'average_rating_num_rating': '4.38 (291)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Perfect location for first time NYC travelers!!', 'num_bed': '1 double bed', 'price_val': '$196', 'price_per_night': '$ 1 9 6   p e r   n i g h t', 'average_rating_num_rating': '4.71 (78)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Lovely  sunshine one bedroom in Queens', 'num_bed': '1 queen bed', 'price_val': '$52', 'price_per_night': '$ 5 2   p e r   n i g h t', 'average_rating_num_rating': '4.6 (62)'}
# listing_data {'title': 'Private room in Brooklyn', 'description': 'Comfy & Spacious King Bedroom', 'num_bed': '1 king bed', 'price_val': '$62', 'price_per_night': '$ 6 2   p e r   n i g h t', 'average_rating_num_rating': '4.74 (263)'}
# listing_data {'title': 'Apartment in Brooklyn', 'description': 'Extremely comfy, chic Greenpoint 💎 gem!', 'num_bed': '1 bed', 'price_val': '$175', 'price_per_night': '$ 1 7 5   p e r   n i g h t', 'average_rating_num_rating': '5.0 (23)'}
# listing_data {'title': 'Hotel room in New York', 'description': 'Beautiful Standard Full Room at The Ridge', 'num_bed': '1 double bed', 'price_val': '$205', 'price_per_night': '$ 2 0 5   p e r   n i g h t', 'average_rating_num_rating': '4.4 (918)'}
# listing_data {'title': 'Private room in Brooklyn', 'description': 'Big Sunny Room in Huge DUMBO Loft', 'num_bed': '1 queen bed', 'price_val': '$164', 'price_per_night': '$ 1 6 4   p e r   n i g h t', 'average_rating_num_rating': '4.95 (294)'}
# listing_data {'title': 'Private room in New York', 'description': 'Cozy Private Bedroom w/access to whole apartment!', 'num_bed': '2 beds', 'price_val': '$79', 'price_per_night': '$ 7 9   p e r   n i g h t', 'average_rating_num_rating': '5.0 (3)'}
# listing_data {'title': 'Private room in New York', 'description': '#4. Peaceful private bedroom in Manhattan.', 'num_bed': '1 bed', 'price_val': '$99', 'price_per_night': '$ 9 9   p e r   n i g h t', 'average_rating_num_rating': '4.87 (53)'}
# listing_data {'title': 'Home in New York', 'description': 'A Simple Studio/Entire Apt/JFK abt 5mi', 'num_bed': '1 bed', 'price_val': '$95', 'price_per_night': '$ 9 5   p e r   n i g h t', 'average_rating_num_rating': '4.91 (317)'}
# listing_data {'title': 'Apartment in New York City', 'description': '1st floor, Beautiful open studio apartment$88', 'num_bed': '1 bed', 'price_val': '$78', 'price_per_night': '$ 7 8   p e r   n i g h t', 'average_rating_num_rating': '4.71 (17)'}
# listing_data {'title': 'Apartment in New York City', 'description': 'Lovely cozy 3 bedroom near Restaurants & Shopping!', 'num_bed': '3 beds', 'price_val': '$117', 'price_per_night': '$ 1 1 7   p e r   n i g h t', 'average_rating_num_rating': '4.93 (57)'}
# listing_data {'title': 'Private room in New York', 'description': 'Cozy Room in DT Near Subway St -5 Min Walk', 'num_bed': '1 bed', 'price_val': '$103', 'price_per_night': '$ 1 0 3   p e r   n i g h t', 'average_rating_num_rating': '4.67 (3)'}
# listing_data {'title': 'Apartment in New York City', 'description': 'Sunny Brownstone Studio in BedStuy Brooklyn', 'num_bed': '1 queen bed', 'price_val': '$168', 'price_per_night': '$ 1 6 8   p e r   n i g h t', 'average_rating_num_rating': '4.84 (269)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Kingsize skylight bedroom in Harlem brownstone', 'num_bed': '1 bed', 'price_val': '$107', 'price_per_night': '$ 1 0 7   p e r   n i g h t', 'average_rating_num_rating': '4.96 (54)'}
# listing_data {'title': 'Private room in New York', 'description': 'Private Room in Spacious Quiet Apt., Elevator Bldg', 'num_bed': '2 queen beds', 'price_val': '$63', 'price_per_night': '$ 6 3   p e r   n i g h t', 'average_rating_num_rating': '4.65 (617)'}
# listing_data {'title': 'Private room in New York', 'description': 'Private bedroom in the heart of NYC', 'num_bed': '1 double bed', 'price_val': '$137', 'price_per_night': '$ 1 3 7   p e r   n i g h t', 'average_rating_num_rating': '4.86 (252)'}
# listing_data {'title': 'Private room in New York City', 'description': 'Affordable bedroom in Brooklyn townhouse.', 'num_bed': '1 queen bed', 'price_val': '$63', 'price_per_night': '$ 6 3   p e r   n i g h t', 'average_rating_num_rating': '4.81 (221)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Cozy room in East Harlem NY', 'num_bed': '1 bed', 'price_val': '$71', 'price_per_night': '$ 7 1   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Minimal room 7 SofaBed + loft bed in Manhattan', 'num_bed': '2 beds', 'price_val': '$68', 'price_per_night': '$ 6 8   p e r   n i g h t', 'average_rating_num_rating': '4.47 (32)'}
# listing_data {'title': 'Private room in New York City', 'description': 'Astoria Bedroom', 'num_bed': '1 bed', 'price_val': '$58', 'price_per_night': '$ 5 8   p e r   n i g h t', 'average_rating_num_rating': '4.93 (42)'}
# listing_data {'title': 'Private room in New York City', 'description': 'Room c', 'num_bed': '1 single bed', 'price_val': '$80', 'price_per_night': '$ 8 0   p e r   n i g h t', 'average_rating_num_rating': '4.9 (98)'}
# listing_data None
# listing_data {'title': 'Private room in North Bergen', 'description': 'Cozy room and 15 min away from Times Square', 'num_bed': '1 bed', 'price_val': '$62', 'price_per_night': '$ 6 2   p e r   n i g h t', 'average_rating_num_rating': '4.85 (27)'}
# listing_data {'title': 'Private room in New York City', 'description': 'Prime Park Slope Room (2 min. walk to subway)', 'num_bed': '1 double bed', 'price_val': '$75', 'price_per_night': '$ 7 5   p e r   n i g h t', 'average_rating_num_rating': '4.96 (264)'}
# listing_data {'title': 'Private room in New York', 'description': 'Historic UWS 1BR Near Subway&Columbia University', 'num_bed': '1 queen bed', 'price_val': '$106', 'price_per_night': '$ 1 0 6   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Apartment in New York', 'description': 'Hell’s Kitchen Oasis', 'num_bed': '1 bed', 'price_val': '$249', 'price_per_night': '$ 2 4 9   p e r   n i g h t', 'average_rating_num_rating': '4.88 (51)'}
# listing_data {'title': 'Hotel room in New York', 'description': 'Two Bathroom Suite steps from Central Park', 'num_bed': '2 beds', 'price_val': '$251', 'price_per_night': '$ 2 5 1   p e r   n i g h t', 'average_rating_num_rating': '4.67 (346)'}
# listing_data {'title': 'Private room in Brooklyn', 'description': 'Heart of Williamsburg', 'num_bed': '1 queen bed', 'price_val': '$125', 'price_per_night': '$ 1 2 5   p e r   n i g h t', 'average_rating_num_rating': '4.95 (125)'}
# listing_data {'title': 'Apartment in New York', 'description': 'LUXURY APT w PRIVATE GARDEN NYC UES', 'num_bed': '1 queen bed', 'price_val': '$245', 'price_per_night': '$ 2 4 5   p e r   n i g h t', 'average_rating_num_rating': '4.7 (369)'}
# listing_data None
# listing_data {'title': 'Hotel room in New York', 'description': 'Beautiful Standard Full Room at The Ridge', 'num_bed': '1 double bed', 'price_val': '$205', 'price_per_night': '$ 2 0 5   p e r   n i g h t', 'average_rating_num_rating': '4.4 (918)'}
# listing_data {'title': 'Apartment in Brooklyn', 'description': 'Best Private Studio In East Flatbush Brooklyn Gem', 'num_bed': '2 beds', 'price_val': '$59', 'price_per_night': '$ 5 9   p e r   n i g h t', 'average_rating_num_rating': '4.79 (164)'}
# listing_data {'title': 'Private room in New York', 'description': 'Historic UWS 1BR Near Subway&Columbia University', 'num_bed': '1 queen bed', 'price_val': '$106', 'price_per_night': '$ 1 0 6   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Private room in New York', 'description': '1 bedroom w/ Queen bed, 5 minutes from Manhattan', 'num_bed': '1 queen bed', 'price_val': '$79', 'price_per_night': '$ 7 9   p e r   n i g h t', 'average_rating_num_rating': '4.94 (352)'}
# listing_data {'title': 'Private room in New York', 'description': 'Private bedroom close to Central Park/Columbia Uni', 'num_bed': '1 bed', 'price_val': '$147', 'price_per_night': '$ 1 4 7   p e r   n i g h t', 'average_rating_num_rating': '4.86 (28)'}
# listing_data {'title': 'Private room in Brooklyn', 'description': 'IDEAL 2 Williamsburg Brooklyn @ Lorimor L train', 'num_bed': '1 double bed', 'price_val': '$70', 'price_per_night': '$ 7 0   p e r   n i g h t', 'average_rating_num_rating': '4.78 (40)'}
# listing_data {'title': 'Private room in New York', 'description': '#4. Peaceful private bedroom in Manhattan.', 'num_bed': '1 bed', 'price_val': '$99', 'price_per_night': '$ 9 9   p e r   n i g h t', 'average_rating_num_rating': '4.87 (53)'}
# listing_data {'title': 'Apartment in Brooklyn', 'description': 'Williamsburg, Brooklyn luxury apt in old church', 'num_bed': '1 double bed', 'price_val': '$199', 'price_per_night': '$ 1 9 9   p e r   n i g h t', 'average_rating_num_rating': '4.88 (16)'}
# listing_data None
# listing_data {'title': 'Apartment in Brooklyn', 'description': 'Sunny Brownstone Studio in BedStuy Brooklyn', 'num_bed': '1 queen bed', 'price_val': '$168', 'price_per_night': '$ 1 6 8   p e r   n i g h t', 'average_rating_num_rating': '4.84 (269)'}
# listing_data {'title': 'Apartment in Brooklyn', 'description': 'One bedroom apartment in Clinton Hill', 'num_bed': '1 queen bed', 'price_val': '$141', 'price_per_night': '$ 1 4 1   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Condo in New York', 'description': 'Quiet 1 Bedroom Flat + Balcony in Manhattan, NYC', 'num_bed': '1 bed', 'price_val': '$134', 'price_per_night': '$ 1 3 4   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Private room in New York', 'description': 'A Fantasy NYC Getaway Stay!', 'num_bed': '1 bed', 'price_val': '$75', 'price_per_night': '$ 7 5   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data None
# listing_data {'title': 'Private room in Brooklyn', 'description': 'Your Happy Place in Brooklyn', 'num_bed': '2 beds', 'price_val': '$46', 'price_per_night': '$ 4 6   p e r   n i g h t', 'average_rating_num_rating': '4.65 (17)'}
# listing_data {'title': 'Shared room in The Bronx', 'description': 'Mott Haven Dorm FF', 'num_bed': '1 single bed', 'price_val': '$25', 'price_per_night': '$ 2 5   p e r   n i g h t', 'average_rating_num_rating': '4.23 (71)'}
# listing_data None
# listing_data None
# listing_data {'title': 'Apartment in New York', 'description': 'A Upper East Side Flat with a Home Office', 'num_bed': '1 bed', 'price_val': '$140', 'price_per_night': '$ 1 4 0   p e r   n i g h t', 'average_rating_num_rating': 'NONE'}
# listing_data {'title': 'Apartment in New York', 'description': 'THE SMALL CHATEAU IN THE TREES', 'num_bed': '2 beds', 'price_val': '$225', 'price_per_night': '$ 2 2 5   p e r   n i g h t', 'average_rating_num_rating': '4.84 (428)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Empire State Studio Apt', 'num_bed': 'Feb 3 – 5', 'price_val': '$160', 'price_per_night': '$ 1 6 0   p e r   n i g h t', 'average_rating_num_rating': '4.7 (107)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Cozy Private Room in Ridgewood', 'num_bed': '1 bed', 'price_val': '$51', 'price_per_night': '$ 5 1   p e r   n i g h t', 'average_rating_num_rating': '4.6 (5)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Cozy apartment next to Fort Tryon Park', 'num_bed': '2 beds', 'price_val': '$159', 'price_per_night': '$ 1 5 9   p e r   n i g h t', 'average_rating_num_rating': '4.87 (15)'}
# listing_data {'title': 'Private room in Weehawken', 'description': 'NYC Skyline view and lovely large bedroom', 'num_bed': 'Dec 23 – 25', 'price_val': '$126', 'price_per_night': '$ 1 2 6   p e r   n i g h t', 'average_rating_num_rating': '4.58 (92)'}
# listing_data {'title': 'Private room in Brooklyn', 'description': 'Charming Bushwick Oasis / Cozy Private Room', 'num_bed': '1 double bed', 'price_val': '$72', 'price_per_night': '$ 7 2   p e r   n i g h t', 'average_rating_num_rating': '4.75 (101)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Cozy apartment in the UES', 'num_bed': '1 bed', 'price_val': '$191', 'price_per_night': '$ 1 9 1   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Private room in Brooklyn', 'description': 'Big Sunny Room in Huge DUMBO Loft', 'num_bed': '1 queen bed', 'price_val': '$164', 'price_per_night': '$ 1 6 4   p e r   n i g h t', 'average_rating_num_rating': '4.95 (294)'}
# listing_data {'title': 'Private room in New York', 'description': 'Shered bathroom 3 SofaBed + loftbed + kitchen', 'num_bed': '2 beds', 'price_val': '$88', 'price_per_night': '$ 8 8   p e r   n i g h t', 'average_rating_num_rating': '4.62 (50)'}
# listing_data {'title': 'Private room in New York', 'description': 'Parkside Chateau', 'num_bed': '1 double bed', 'price_val': '$80', 'price_per_night': '$ 8 0   p e r   n i g h t', 'average_rating_num_rating': '4.77 (61)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Spacious and Sun-Kissed 1-Bedroom in South Harlem!', 'num_bed': '1 bed', 'price_val': '$150', 'price_per_night': '$ 1 5 0   p e r   n i g h t', 'average_rating_num_rating': '5.0 (4)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Big Cozy Brand New Sunny Studio in Flushing NY!', 'num_bed': '2 double beds', 'price_val': '$79', 'price_per_night': '$ 7 9   p e r   n i g h t', 'average_rating_num_rating': '4.96 (280)'}
# listing_data {'title': 'Private room in New York', 'description': '1 bedroom w/ Queen bed, 5 minutes from Manhattan', 'num_bed': '1 queen bed', 'price_val': '$79', 'price_per_night': '$ 7 9   p e r   n i g h t', 'average_rating_num_rating': '4.94 (352)'}
# listing_data {'title': 'Private room in Brooklyn', 'description': 'Studio with private bathroom and kitchenette', 'num_bed': '1 bed', 'price_val': '$100', 'price_per_night': '$ 1 0 0   p e r   n i g h t', 'average_rating_num_rating': '4.88 (25)'}
# listing_data {'title': 'Private room in New York', 'description': 'Private room with Shared bath on Union Square 4', 'num_bed': '2 beds', 'price_val': '$69', 'price_per_night': '$ 6 9   p e r   n i g h t', 'average_rating_num_rating': '4.37 (38)'}
# listing_data {'title': 'Private room in New York', 'description': 'Penthouse Studio East 50s with Roof Terrace', 'num_bed': '1 queen bed', 'price_val': '$247', 'price_per_night': '$ 2 4 7   p e r   n i g h t', 'average_rating_num_rating': '4.98 (120)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Cozy studio apt in the heart of Chinatown', 'num_bed': '1 double bed', 'price_val': '$178', 'price_per_night': '$ 1 7 8   p e r   n i g h t', 'average_rating_num_rating': '5.0 (12)'}
# listing_data {'title': 'Home in New York', 'description': '1Bedroom (Free-Parking)', 'num_bed': '2 beds', 'price_val': '$60', 'price_per_night': '$ 6 0   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Private room in New York', 'description': '#1. Pleasant private bedroom in Manhattan.', 'num_bed': '1 bed', 'price_val': '$72', 'price_per_night': '$ 7 2   p e r   n i g h t', 'average_rating_num_rating': '4.73 (41)'}
# listing_data {'title': 'Private room in New York', 'description': 'Penthouse Studio East 50s with Roof Terrace', 'num_bed': '1 queen bed', 'price_val': '$247', 'price_per_night': '$ 2 4 7   p e r   n i g h t', 'average_rating_num_rating': '4.98 (120)'}
# listing_data None
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Private Bedroom in Manhattan', 'num_bed': '1 bed', 'price_val': '$52', 'price_per_night': '$ 5 2   p e r   n i g h t', 'average_rating_num_rating': '4.23 (61)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Steps from Times Square, Transportation & Broadway', 'num_bed': '2 beds', 'price_val': '$165', 'price_per_night': '$ 1 6 5   p e r   n i g h t', 'average_rating_num_rating': '4.07 (15)'}
# listing_data None
# listing_data {'title': 'Private room in Brooklyn', 'description': 'Private suite in a Landmarked Brooklyn Brownstone', 'num_bed': '3 beds', 'price_val': '$100', 'price_per_night': '$ 1 0 0   p e r   n i g h t', 'average_rating_num_rating': '4.96 (23)'}
# listing_data None
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Room close to  Manhattan for FEMALE guests', 'num_bed': '1 single bed', 'price_val': '$75', 'price_per_night': '$ 7 5   p e r   n i g h t', 'average_rating_num_rating': '4.89 (9)'}
# listing_data {'title': 'Private room in New York', 'description': 'Huge Bedroom w/bathroom next to Columbia U!', 'num_bed': '1 double bed', 'price_val': '$100', 'price_per_night': '$ 1 0 0   p e r   n i g h t', 'average_rating_num_rating': '4.77 (186)'}
# listing_data {'title': 'Apartment in New York', 'description': 'UNTITLED at Freeman - Double Studio 317', 'num_bed': '1 double bed', 'price_val': '$228', 'price_per_night': '$ 2 2 8   p e r   n i g h t', 'average_rating_num_rating': '4.86 (63)'}
# listing_data {'title': 'Private room in New York', 'description': 'Cozy room in East Village with AC', 'num_bed': '2 single beds', 'price_val': '$92', 'price_per_night': '$ 9 2   p e r   n i g h t', 'average_rating_num_rating': '4.35 (212)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Lovely 2 bedroom Apt 5PPL NYC', 'num_bed': '4 beds', 'price_val': '$205', 'price_per_night': '$ 2 0 5   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Spacious and Lovely One Bedroom', 'num_bed': '1 queen bed', 'price_val': '$102', 'price_per_night': '$ 1 0 2   p e r   n i g h t', 'average_rating_num_rating': '4.98 (58)'}
# listing_data {'title': 'Apartment in Jersey City', 'description': 'Near Time Square NYC /only 4.2 miles to 42 Nd St', 'num_bed': '3 beds', 'price_val': '$98', 'price_per_night': '$ 9 8   p e r   n i g h t', 'average_rating_num_rating': '4.3 (64)'}
# listing_data None
# listing_data {'title': 'Hotel room in New York', 'description': 'Amazing Micro Unit W/ communal rooftop and kitchen', 'num_bed': '1 queen bed', 'price_val': '$210', 'price_per_night': '$ 2 1 0   p e r   n i g h t', 'average_rating_num_rating': '4.55 (1499)'}
# listing_data {'title': 'Apartment in Staten Island', 'description': 'Bright and airy 2-bedroom apt on Staten Island', 'num_bed': '2 beds', 'price_val': '$90', 'price_per_night': '$ 9 0   p e r   n i g h t', 'average_rating_num_rating': '4.89 (55)'}
# listing_data None
# listing_data {'title': 'Apartment in Brooklyn', 'description': 'Ocean Hill Oasis', 'num_bed': '3 beds', 'price_val': '$100', 'price_per_night': '$ 1 0 0   p e r   n i g h t', 'average_rating_num_rating': '4.56 (220)'}
# listing_data {'title': 'Apartment in Brooklyn', 'description': 'Leafy brownstone, ideal for solo traveler', 'num_bed': '1 single bed', 'price_val': '$135', 'price_per_night': '$ 1 3 5   p e r   n i g h t', 'average_rating_num_rating': '4.9 (10)'}
# listing_data None
# listing_data None
# listing_data None
# listing_data {'title': 'Private room in Brooklyn', 'description': 'Private suite in a Landmarked Brooklyn Brownstone', 'num_bed': '3 beds', 'price_val': '$100', 'price_per_night': '$ 1 0 0   p e r   n i g h t', 'average_rating_num_rating': '4.96 (23)'}
# listing_data None
# listing_data {'title': 'Private room in New York', 'description': 'Private Bedroom in Manhattan', 'num_bed': '1 bed', 'price_val': '$52', 'price_per_night': '$ 5 2   p e r   n i g h t', 'average_rating_num_rating': '4.23 (61)'}
# listing_data {'title': 'Apartment in New York', 'description': 'Studio Artitaje in Harlem', 'num_bed': '2 beds', 'price_val': '$93', 'price_per_night': '$ 9 3   p e r   n i g h t', 'average_rating_num_rating': 'New'}
# listing_data {'title': 'Private room in West New York', 'description': 'Private Room, 20 min of NYC beautifully', 'num_bed': '1 queen bed', 'price_val': '$68', 'price_per_night': '$ 6 8   p e r   n i g h t', 'average_rating_num_rating': '4.88 (17)'}
# listing_data None
# listing_data {'title': 'Apartment in New York', 'description': '🌟Elite Manhattan Studio with Gym and Roof deck🌟', 'num_bed': '1 bed', 'price_val': '$124', 'price_per_night': '$ 1 2 4   p e r   n i g h t', 'average_rating_num_rating': '4.7 (44)'}
# listing_data {'title': 'Apartment in New York', 'description': 'UNTITLED at Freeman - Double Studio 317', 'num_bed': '1 double bed', 'price_val': '$228', 'price_per_night': '$ 2 2 8   p e r   n i g h t', 'average_rating_num_rating': '4.86 (63)'}
# listing_data {'title': 'Private room in New York', 'description': 'Big Bedrm in Manhattan near Central Park & Subway', 'num_bed': '1 bed', 'price_val': '$79', 'price_per_night': '$ 7 9   p e r   n i g h t', 'average_rating_num_rating': '4.86 (22)'}
# listing_data {'title': 'Apartment in Brooklyn', 'description': 'Artsy Bsmnt Apt in Bklyn Brownstone', 'num_bed': '1 double bed', 'price_val': '$115', 'price_per_night': '$ 1 1 5   p e r   n i g h t', 'average_rating_num_rating': '4.83 (143)'}
# listing_data {'title': 'Townhouse in Brooklyn', 'description': 'Private floor in Modern, Hip Brooklyn Brownstone!', 'num_bed': '2 beds', 'price_val': '$180', 'price_per_night': '$ 1 8 0   p e r   n i g h t', 'average_rating_num_rating': '4.95 (134)'}

# %%
# Load data into a data frame - NEED TO DO DATA CLEANING HERE BEFORE EXPORTING TO CSV!
df = pd.DataFrame(df_data)
df.head()
# Out:
#                            title  \
# 0       Private room in New York
# 1       Private room in New York
# 2  Private room in New York City
# 3  Private room in New York City
# 4       Private room in New York
#
#                                       description      num_beds price_val  \
# 0                           spacious chelsea room  1 double bed       $77
# 1  Minimal room 4 SofaBed + loft bed in Manhattan        2 beds       $79
# 2                   Comfortable and clean bedroom  1 double bed       $65
# 3          Cozy, quiet room in artist's apartment  1 single bed       $49
# 4  [Manhattan Heart] 800m to Time Square/Broadway         1 bed      $126
#
#                price_per_night average_rating_num_rating
# 0    $ 7 7   p e r   n i g h t                 4.91 (98)
# 1    $ 7 9   p e r   n i g h t                4.44 (117)
# 2    $ 6 5   p e r   n i g h t                4.84 (151)
# 3    $ 4 9   p e r   n i g h t                4.78 (120)
# 4  $ 1 2 6   p e r   n i g h t                 4.91 (23)

# %%
df["title"] = df["title"].astype("string")
df["description"] = df["description"].astype("string")
df["num_beds"] = df["num_beds"].astype("string")

df["price_val_usd"] = df["price_val"].apply(lambda x: int(x[1:]))
df["price_val_usd"] = df["price_val_usd"].astype("int32")

# %%
def get_total_stars(x):
    left_parenthesis = x.find("(")
    if left_parenthesis == -1:
        return 0
    right_parenthesis = len(x) - 1
    total_star = float(x[:left_parenthesis-1])
    return total_star

def get_num_review(x):
    left_parenthesis = x.find("(")
    if left_parenthesis == -1:
        return 0
    right_parenthesis = len(x) - 1
    num_review = int(x[left_parenthesis+1: right_parenthesis])
    
    return num_review

# %%
df["total_star"] = df["average_rating_num_rating"].apply(get_total_stars)
df["num_review"] =   df["average_rating_num_rating"].apply(get_num_review).astype("int32")

# %%
df = df.drop(columns=["price_per_night", "average_rating_num_rating", "price_val"])
df
# Out:
#                              title  \
# 0         Private room in New York
# 1         Private room in New York
# 2    Private room in New York City
# 3    Private room in New York City
# 4         Private room in New York
# ..                             ...
# 207          Apartment in New York
# 208          Apartment in New York
# 209       Private room in New York
# 210          Apartment in Brooklyn
# 211          Townhouse in Brooklyn
#
#                                            description      num_beds  \
# 0                                spacious chelsea room  1 double bed
# 1       Minimal room 4 SofaBed + loft bed in Manhattan        2 beds
# 2                        Comfortable and clean bedroom  1 double bed
# 3               Cozy, quiet room in artist's apartment  1 single bed
# 4       [Manhattan Heart] 800m to Time Square/Broadway         1 bed
# ..                                                 ...           ...
# 207    🌟Elite Manhattan Studio with Gym and Roof deck🌟         1 bed
# 208            UNTITLED at Freeman - Double Studio 317  1 double bed
# 209  Big Bedrm in Manhattan near Central Park & Subway         1 bed
# 210                Artsy Bsmnt Apt in Bklyn Brownstone  1 double bed
# 211  Private floor in Modern, Hip Brooklyn Brownstone!        2 beds
#
#      price_val_usd  total_star  num_review
# 0               77        4.91          98
# 1               79        4.44         117
# 2               65        4.84         151
# 3               49        4.78         120
# 4              126        4.91          23
# ..             ...         ...         ...
# 207            124        4.70          44
# 208            228        4.86          63
# 209             79        4.86          22
# 210            115        4.83         143
# 211            180        4.95         134
#
# [212 rows x 6 columns]

# %%
df.head()
# Out:
#                            title  \
# 0       Private room in New York
# 1       Private room in New York
# 2  Private room in New York City
# 3  Private room in New York City
# 4       Private room in New York
#
#                                       description      num_beds  \
# 0                           spacious chelsea room  1 double bed
# 1  Minimal room 4 SofaBed + loft bed in Manhattan        2 beds
# 2                   Comfortable and clean bedroom  1 double bed
# 3          Cozy, quiet room in artist's apartment  1 single bed
# 4  [Manhattan Heart] 800m to Time Square/Broadway         1 bed
#
#    price_val_usd  total_star  num_review
# 0             77        4.91          98
# 1             79        4.44         117
# 2             65        4.84         151
# 3             49        4.78         120
# 4            126        4.91          23

# %%
df[df["total_star"] == 0]
# Out:
#                              title  \
# 23           Apartment in New York
# 39        Private room in New York
# 45        Private room in New York
# 54        Private room in Brooklyn
# 61           Apartment in New York
# 64           Apartment in New York
# 66           Apartment in New York
# 78   Private room in New York City
# 79           Apartment in New York
# 107          Apartment in New York
# 108          Apartment in New York
# 117               Home in New York
# 124       Private room in Brooklyn
# 143       Private room in New York
# 149       Private room in New York
# 156       Private room in New York
# 163          Apartment in Brooklyn
# 164              Condo in New York
# 165       Private room in New York
# 168          Apartment in New York
# 175          Apartment in New York
# 186               Home in New York
# 196          Apartment in New York
# 205          Apartment in New York
#
#                                            description     num_beds  \
# 23   Studio with 1 Queen Bed at Candlewood Suites T...  1 queen bed
# 39                        Cozy room at LOWER EAST SIDE        1 bed
# 45                        Cozy room at LOWER EAST SIDE        1 bed
# 54              Private Room Near Major Transportation        1 bed
# 61             Adorable one bedroom in upper east side        1 bed
# 64                           Studio Artitaje in Harlem       2 beds
# 66                    Hell’s Kitchen 1BR Holiday Deal!        1 bed
# 78              Private Room Near Major Transportation        1 bed
# 79      Cozy Studio in the Heart of Midtown Manhattan!        1 bed
# 107          A Upper East Side Flat with a Home Office        1 bed
# 108   Brand New Alcove Studio right by One World Trade        1 bed
# 117                           2 Bedroom (Free-Parking)       3 beds
# 124    Cozy and Sunny Private Room in Central Brooklyn        1 bed
# 143                        Cozy room in East Harlem NY        1 bed
# 149   Historic UWS 1BR Near Subway&Columbia University  1 queen bed
# 156   Historic UWS 1BR Near Subway&Columbia University  1 queen bed
# 163              One bedroom apartment in Clinton Hill  1 queen bed
# 164   Quiet 1 Bedroom Flat + Balcony in Manhattan, NYC        1 bed
# 165                        A Fantasy NYC Getaway Stay!        1 bed
# 168          A Upper East Side Flat with a Home Office        1 bed
# 175                          Cozy apartment in the UES        1 bed
# 186                            1Bedroom (Free-Parking)       2 beds
# 196                      Lovely 2 bedroom Apt 5PPL NYC       4 beds
# 205                          Studio Artitaje in Harlem       2 beds
#
#      price_val_usd  total_star  num_review
# 23             109         0.0           0
# 39              88         0.0           0
# 45              88         0.0           0
# 54              53         0.0           0
# 61             135         0.0           0
# 64              93         0.0           0
# 66             143         0.0           0
# 78              53         0.0           0
# 79             171         0.0           0
# 107            140         0.0           0
# 108            200         0.0           0
# 117             65         0.0           0
# 124             74         0.0           0
# 143             71         0.0           0
# 149            106         0.0           0
# 156            106         0.0           0
# 163            141         0.0           0
# 164            134         0.0           0
# 165             75         0.0           0
# 168            140         0.0           0
# 175            191         0.0           0
# 186             60         0.0           0
# 196            205         0.0           0
# 205             93         0.0           0

# %%
df[df["total_star"] == 0]
# Out:
#                              title  \
# 23           Apartment in New York
# 39        Private room in New York
# 45        Private room in New York
# 54        Private room in Brooklyn
# 61           Apartment in New York
# 64           Apartment in New York
# 66           Apartment in New York
# 78   Private room in New York City
# 79           Apartment in New York
# 107          Apartment in New York
# 108          Apartment in New York
# 117               Home in New York
# 124       Private room in Brooklyn
# 143       Private room in New York
# 149       Private room in New York
# 156       Private room in New York
# 163          Apartment in Brooklyn
# 164              Condo in New York
# 165       Private room in New York
# 168          Apartment in New York
# 175          Apartment in New York
# 186               Home in New York
# 196          Apartment in New York
# 205          Apartment in New York
#
#                                            description     num_beds  \
# 23   Studio with 1 Queen Bed at Candlewood Suites T...  1 queen bed
# 39                        Cozy room at LOWER EAST SIDE        1 bed
# 45                        Cozy room at LOWER EAST SIDE        1 bed
# 54              Private Room Near Major Transportation        1 bed
# 61             Adorable one bedroom in upper east side        1 bed
# 64                           Studio Artitaje in Harlem       2 beds
# 66                    Hell’s Kitchen 1BR Holiday Deal!        1 bed
# 78              Private Room Near Major Transportation        1 bed
# 79      Cozy Studio in the Heart of Midtown Manhattan!        1 bed
# 107          A Upper East Side Flat with a Home Office        1 bed
# 108   Brand New Alcove Studio right by One World Trade        1 bed
# 117                           2 Bedroom (Free-Parking)       3 beds
# 124    Cozy and Sunny Private Room in Central Brooklyn        1 bed
# 143                        Cozy room in East Harlem NY        1 bed
# 149   Historic UWS 1BR Near Subway&Columbia University  1 queen bed
# 156   Historic UWS 1BR Near Subway&Columbia University  1 queen bed
# 163              One bedroom apartment in Clinton Hill  1 queen bed
# 164   Quiet 1 Bedroom Flat + Balcony in Manhattan, NYC        1 bed
# 165                        A Fantasy NYC Getaway Stay!        1 bed
# 168          A Upper East Side Flat with a Home Office        1 bed
# 175                          Cozy apartment in the UES        1 bed
# 186                            1Bedroom (Free-Parking)       2 beds
# 196                      Lovely 2 bedroom Apt 5PPL NYC       4 beds
# 205                          Studio Artitaje in Harlem       2 beds
#
#      price_val_usd  total_star  num_review
# 23             109         0.0           0
# 39              88         0.0           0
# 45              88         0.0           0
# 54              53         0.0           0
# 61             135         0.0           0
# 64              93         0.0           0
# 66             143         0.0           0
# 78              53         0.0           0
# 79             171         0.0           0
# 107            140         0.0           0
# 108            200         0.0           0
# 117             65         0.0           0
# 124             74         0.0           0
# 143             71         0.0           0
# 149            106         0.0           0
# 156            106         0.0           0
# 163            141         0.0           0
# 164            134         0.0           0
# 165             75         0.0           0
# 168            140         0.0           0
# 175            191         0.0           0
# 186             60         0.0           0
# 196            205         0.0           0
# 205             93         0.0           0

# %%
# # Export CSV - commented out temporarily
# count=1
# file_name = "airbnb_scraped_listings_{}.csv".format(random.getrandbits(128))
# pd.DataFrame(df_data).to_csv(file_name, encoding="utf-8")
# print("Generated_file: {}".format(file_name))
