# %%
'''"Label (Grouping)",
"HOUSING OCCUPANCY",
"HOUSING OCCUPANCY!!Total housing units",
"HOUSING OCCUPANCY!!Total housing units!!Occupied housing units",
"HOUSING OCCUPANCY!!Total housing units!!Vacant housing units",
"HOUSING OCCUPANCY!!Total housing units!!Homeowner vacancy rate",
"HOUSING OCCUPANCY!!Total housing units!!Rental vacancy rate",
"UNITS IN STRUCTURE",
"UNITS IN STRUCTURE!!Total housing units",
"UNITS IN STRUCTURE!!Total housing units!!1-unit,detached",
"UNITS IN STRUCTURE!!Total housing units!!1-unit,attached",
"UNITS IN STRUCTURE!!Total housing units!!2 units",
"UNITS IN STRUCTURE!!Total housing units!!3 or 4 units",
"UNITS IN STRUCTURE!!Total housing units!!5 to 9 units",
"UNITS IN STRUCTURE!!Total housing units!!10 to 19 units",
"UNITS IN STRUCTURE!!Total housing units!!20 or more units",
"UNITS IN STRUCTURE!!Total housing units!!Mobile home",
"UNITS IN STRUCTURE!!Total housing units!!Boat, RV, van,etc.",
"ROOMS",
"ROOMS!!Total housing units",
"ROOMS!!Total housing units!!1 room",
"ROOMS!!Total housing units!!2 rooms",
"ROOMS!!Total housing units!!3 rooms",
"ROOMS!!Total housing units!!4 rooms",
"ROOMS!!Total housing units!!5 rooms",
"ROOMS!!Total housing units!!6 rooms",
"ROOMS!!Total housing units!!7 rooms",
"ROOMS!!Total housing units!!8 rooms",
"ROOMS!!Total housing units!!9 rooms or more",
"ROOMS!!Total housing units!!Median rooms",
"BEDROOMS",
"BEDROOMS!!Total housing units",
"BEDROOMS!!Total housing units!!No bedroom",
"BEDROOMS!!Total housing units!!1 bedroom",
"BEDROOMS!!Total housing units!!2 bedrooms",
"BEDROOMS!!Total housing units!!3 bedrooms",
"BEDROOMS!!Total housing units!!4 bedrooms",
"BEDROOMS!!Total housing units!!5 or more bedrooms",
"HOUSING TENURE",
"HOUSING TENURE!!Occupied housing units",
"HOUSING TENURE!!Occupied housing units!!Owner-occupied",
"HOUSING TENURE!!Occupied housing units!!Renter-occupied",
"HOUSING TENURE!!Occupied housing units!!Average household size of owner-occupied unit",
"HOUSING TENURE!!Occupied housing units!!Average household size of renter-occupied unit",
"YEAR HOUSEHOLDER MOVED INTO UNIT",
"YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units",
"YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units!!Moved in 2019 or later",
"YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units!!Moved in 2015 to 2018",
"YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units!!Moved in 2010 to 2014",
"YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units!!Moved in 2000 to 2009",
"YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units!!Moved in 1990 to 1999",
"YEAR HOUSEHOLDER MOVED INTO UNIT!!Occupied housing units!!Moved in 1989 and earlier",
"VEHICLES AVAILABLE",
"VEHICLES AVAILABLE!!Occupied housing units",
"VEHICLES AVAILABLE!!Occupied housing units!!No vehicles available",
"VEHICLES AVAILABLE!!Occupied housing units!!1 vehicle available",
"VEHICLES AVAILABLE!!Occupied housing units!!2 vehicles available",
"VEHICLES AVAILABLE!!Occupied housing units!!3 or more vehicles available",
"HOUSE HEATING FUEL",
"HOUSE HEATING FUEL!!Occupied housing units",
"HOUSE HEATING FUEL!!Occupied housing units!!Utility gas",
"HOUSE HEATING FUEL!!Occupied housing units!!Bottled,
 tank,
 or LP gas",
"HOUSE HEATING FUEL!!Occupied housing units!!Electricity",
"HOUSE HEATING FUEL!!Occupied housing units!!Fuel oil,
 kerosene,
 etc.",
"HOUSE HEATING FUEL!!Occupied housing units!!Coal or coke",
"HOUSE HEATING FUEL!!Occupied housing units!!Wood",
"HOUSE HEATING FUEL!!Occupied housing units!!Solar energy",
"HOUSE HEATING FUEL!!Occupied housing units!!Other fuel",
"HOUSE HEATING FUEL!!Occupied housing units!!No fuel used",
"SELECTED CHARACTERISTICS",
"SELECTED CHARACTERISTICS!!Occupied housing units",
"SELECTED CHARACTERISTICS!!Occupied housing units!!Lacking complete plumbing facilities",
"SELECTED CHARACTERISTICS!!Occupied housing units!!Lacking complete kitchen facilities",
"SELECTED CHARACTERISTICS!!Occupied housing units!!No telephone service available",
"OCCUPANTS PER ROOM",
"OCCUPANTS PER ROOM!!Occupied housing units",
"OCCUPANTS PER ROOM!!Occupied housing units!!1.00 or less",
"OCCUPANTS PER ROOM!!Occupied housing units!!1.01 to 1.50",
"OCCUPANTS PER ROOM!!Occupied housing units!!1.51 or more",
"VALUE",
"VALUE!!Owner-occupied units",
"VALUE!!Owner-occupied units!!Less than $50,
000",
"VALUE!!Owner-occupied units!!$50,
000 to $99,
999",
"VALUE!!Owner-occupied units!!$100,
000 to $149,
999",
"VALUE!!Owner-occupied units!!$150,
000 to $199,
999",
"VALUE!!Owner-occupied units!!$200,
000 to $299,
999",
"VALUE!!Owner-occupied units!!$300,
000 to $499,
999",
"VALUE!!Owner-occupied units!!$500,
000 to $999,
999",
"VALUE!!Owner-occupied units!!$1,
000,
000 or more",
"VALUE!!Owner-occupied units!!Median (dollars)",
"MORTGAGE STATUS",
"MORTGAGE STATUS!!Owner-occupied units",
"MORTGAGE STATUS!!Owner-occupied units!!Housing units with a mortgage",
"MORTGAGE STATUS!!Owner-occupied units!!Housing units without a mortgage",
"SELECTED MONTHLY OWNER COSTS (SMOC)",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!Less than $500",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$500 to $999",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$1,
000 to $1,
499",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$1,
500 to $1,
999",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$2,
000 to $2,
499",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$2,
500 to $2,
999",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!$3,
000 or more",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units with a mortgage!!Median (dollars)",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!Less than $250",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!$250 to $399",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!$400 to $599",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!$600 to $799",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!$800 to $999",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!$1,
000 or more",
"SELECTED MONTHLY OWNER COSTS (SMOC)!!Housing units without a mortgage!!Median (dollars)",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)!!Less than 20.0 percent",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)!!20.0 to 24.9 percent",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)!!25.0 to 29.9 percent",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)!!30.0 to 34.9 percent",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)!!35.0 percent or more",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing units with a mortgage (excluding units where SMOCAPI cannot be computed)!!Not computed",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)!!Less than 10.0 percent",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)!!10.0 to 14.9 percent",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)!!15.0 to 19.9 percent",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)!!20.0 to 24.9 percent",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)!!25.0 to 29.9 percent",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)!!30.0 to 34.9 percent",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)!!35.0 percent or more",
"SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)!!Housing unit without a mortgage (excluding units where SMOCAPI cannot be computed)!!Not computed",
"GROSS RENT",
"GROSS RENT!!Occupied units paying rent",
"GROSS RENT!!Occupied units paying rent!!Less than $500",
"GROSS RENT!!Occupied units paying rent!!$500 to $999",
"GROSS RENT!!Occupied units paying rent!!$1,
000 to $1,
499",
"GROSS RENT!!Occupied units paying rent!!$1,
500 to $1,
999",
"GROSS RENT!!Occupied units paying rent!!$2,
000 to $2,
499",
"GROSS RENT!!Occupied units paying rent!!$2,
500 to $2,
999",
"GROSS RENT!!Occupied units paying rent!!$3,
000 or more",
"GROSS RENT!!Occupied units paying rent!!Median (dollars)",
"GROSS RENT!!Occupied units paying rent!!No rent paid",
"GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)",
"GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)",
"GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!Less than 15.0 percent",
"GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!15.0 to 19.9 percent",
"GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!20.0 to 24.9 percent",
"GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!25.0 to 29.9 percent",
"GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!30.0 to 34.9 percent",
"GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!35.0 percent or more",
"GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!Not computed"
'''

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
#skipinitialspace=True, , usecols=copy_cols
copy_cols=["Label (Grouping)","HOUSING OCCUPANCY","HOUSING OCCUPANCY!!Total housing units",
           "HOUSING OCCUPANCY!!Total housing units!!Occupied housing units","HOUSING OCCUPANCY!!Total housing units!!Vacant housing units",
           "ROOMS!!Total housing units!!1 room","ROOMS!!Total housing units!!2 rooms",
           "ROOMS!!Total housing units!!3 rooms","ROOMS!!Total housing units!!4 rooms",
           "ROOMS!!Total housing units!!5 rooms","ROOMS!!Total housing units!!6 rooms",
           "ROOMS!!Total housing units!!7 rooms","ROOMS!!Total housing units!!8 rooms",
           "ROOMS!!Total housing units!!9 rooms or more","ROOMS!!Total housing units!!Median rooms",
           "BEDROOMS!!Total housing units!!No bedroom","BEDROOMS!!Total housing units!!1 bedroom",
           "BEDROOMS!!Total housing units!!2 bedrooms","BEDROOMS!!Total housing units!!3 bedrooms",
           "BEDROOMS!!Total housing units!!4 bedrooms","BEDROOMS!!Total housing units!!5 or more bedrooms",
           "HOUSING TENURE!!Occupied housing units","HOUSING TENURE!!Occupied housing units!!Owner-occupied",
           "HOUSING TENURE!!Occupied housing units!!Renter-occupied",
#           "OCCUPANTS PER ROOM!!Occupied housing units!!1.00 or less",
#           "OCCUPANTS PER ROOM!!Occupied housing units!!1.01 to 1.50",
#           "OCCUPANTS PER ROOM!!Occupied housing units!!1.51 or more","VALUE!!Owner-occupied units",
#           "VALUE!!Owner-occupied units!!Less than $50,000","VALUE!!Owner-occupied units!!$50,000 to $99,999",
#           "VALUE!!Owner-occupied units!!$100,000 to $149,999","VALUE!!Owner-occupied units!!$150,000 to $199,999",
#           "VALUE!!Owner-occupied units!!$200,000 to $299,999","VALUE!!Owner-occupied units!!$300,000 to $499,999",
#           "VALUE!!Owner-occupied units!!$500,000 to $999,999","VALUE!!Owner-occupied units!!$1,000,000 or more",
           "VALUE!!Owner-occupied units!!Median (dollars)","GROSS RENT!!Occupied units paying rent",
#           "GROSS RENT!!Occupied units paying rent!!Less than $500",
#          "GROSS RENT!!Occupied units paying rent!!$500 to $999",
#           "GROSS RENT!!Occupied units paying rent!!$1,000 to $1,499",
#           "GROSS RENT!!Occupied units paying rent!!$1,500 to $1,999",
#           "GROSS RENT!!Occupied units paying rent!!$2,000 to $2,499",
#           "GROSS RENT!!Occupied units paying rent!!$2,500 to $2,999",
#           "GROSS RENT!!Occupied units paying rent!!$3,000 or more",
           "GROSS RENT!!Occupied units paying rent!!Median (dollars)",]


df = pd.read_csv('data/ACS_2021.csv', usecols = copy_cols,low_memory = False)
temp20 = pd.read_csv('data/ACS_2020.csv', usecols = copy_cols,low_memory = False)
temp19 = pd.read_csv('data/ACS_2019.csv', usecols = copy_cols,low_memory = False)
temp18 = pd.read_csv('data/ACS_2018.csv', usecols = copy_cols,low_memory = False)
temp17 = pd.read_csv('data/ACS_2017.csv', usecols = copy_cols,low_memory = False)
temp16 = pd.read_csv('data/ACS_2016.csv', usecols = copy_cols,low_memory = False)
temp15 = pd.read_csv('data/ACS_2015.csv', usecols = copy_cols,low_memory = False)
temp14 = pd.read_csv('data/ACS_2014.csv', usecols = copy_cols,low_memory = False)
temp13 = pd.read_csv('data/ACS_2013.csv', usecols = copy_cols,low_memory = False)
#temp12 = pd.read_csv('data/ACS_2012.csv', usecols = copy_cols,low_memory = False)
#temp11 = pd.read_csv('data/ACS_2011.csv', usecols = copy_cols,low_memory = False)
#temp10 = pd.read_csv('data/ACS_2010.csv', usecols = copy_cols,low_memory = False)

# %%
df = pd.read_csv('data/ACS_2021.csv', low_memory = False)
temp20 = pd.read_csv('data/ACS_2020.csv', low_memory = False)
temp19 = pd.read_csv('data/ACS_2019.csv', low_memory = False)
temp18 = pd.read_csv('data/ACS_2018.csv', low_memory = False)
temp17 = pd.read_csv('data/ACS_2017.csv', low_memory = False)
temp16 = pd.read_csv('data/ACS_2016.csv', low_memory = False)
temp15 = pd.read_csv('data/ACS_2015.csv', low_memory = False)
temp14 = pd.read_csv('data/ACS_2014.csv', low_memory = False)
temp13 = pd.read_csv('data/ACS_2013.csv', low_memory = False)
temp12 = pd.read_csv('data/ACS_2012.csv', low_memory = False)
temp11 = pd.read_csv('data/ACS_2011.csv', low_memory = False)
temp10 = pd.read_csv('data/ACS_2010.csv', low_memory = False)
# Out:
#                                     Label (Grouping)  HOUSING OCCUPANCY  \
# 0              Bronx borough, Bronx County, New York                NaN
# 1                                           Estimate                NaN
# 2                                    Margin of Error                NaN
# 3                                            Percent                NaN
# 4                            Percent Margin of Error                NaN
# 5           Brooklyn borough, Kings County, New York                NaN
# 6                                           Estimate                NaN
# 7                                    Margin of Error                NaN
# 8                                            Percent                NaN
# 9                            Percent Margin of Error                NaN
# 10      Manhattan borough, New York County, New York                NaN
# 11                                          Estimate                NaN
# 12                                   Margin of Error                NaN
# 13                                           Percent                NaN
# 14                           Percent Margin of Error                NaN
# 15           Queens borough, Queens County, New York                NaN
# 16                                          Estimate                NaN
# 17                                   Margin of Error                NaN
# 18                                           Percent                NaN
# 19                           Percent Margin of Error                NaN
# 20  Staten Island borough, Richmond County, New York                NaN
# 21                                          Estimate                NaN
# 22                                   Margin of Error                NaN
# 23                                           Percent                NaN
# 24                           Percent Margin of Error                NaN
#
#    HOUSING OCCUPANCY!!Total housing units  \
# 0                                     NaN
# 1                                 514,051
# 2                                  ±1,413
# 3                                 514,051
# 4                                     (X)
# 5                                     NaN
# 6                               1,003,114
# 7                                  ±1,441
# 8                               1,003,114
# 9                                     (X)
# 10                                    NaN
# 11                                850,490
# 12                                 ±3,152
# 13                                850,490
# 14                                    (X)
# 15                                    NaN
# 16                                840,147
# 17                                   ±952
# 18                                840,147
# 19                                    (X)
# 20                                    NaN
# 21                                177,479
# 22                                   ±586
# 23                                177,479
# 24                                    (X)
#
#    HOUSING OCCUPANCY!!Occupied housing units  \
# 0                                        NaN
# 1                                    475,978
# 2                                     ±3,477
# 3                                      92.6%
# 4                                       ±0.6
# 5                                        NaN
# 6                                    919,333
# 7                                     ±4,390
# 8                                      91.6%
# 9                                       ±0.4
# 10                                       NaN
# 11                                   746,686
# 12                                    ±7,896
# 13                                     87.8%
# 14                                      ±0.8
# 15                                       NaN
# 16                                   780,349
# 17                                    ±3,618
# 18                                     92.9%
# 19                                      ±0.4
# 20                                       NaN
# 21                                   163,468
# 22                                    ±1,986
# 23                                     92.1%
# 24                                      ±1.1
#
#    HOUSING OCCUPANCY!!Vacant housing units  \
# 0                                      NaN
# 1                                   38,073
# 2                                   ±3,063
# 3                                     7.4%
# 4                                     ±0.6
# 5                                      NaN
# 6                                   83,781
# 7                                   ±4,248
# 8                                     8.4%
# 9                                     ±0.4
# 10                                     NaN
# 11                                 103,804
# 12                                  ±6,796
# 13                                   12.2%
# 14                                    ±0.8
# 15                                     NaN
# 16                                  59,798
# 17                                  ±3,622
# 18                                    7.1%
# 19                                    ±0.4
# 20                                     NaN
# 21                                  14,011
# 22                                  ±1,946
# 23                                    7.9%
# 24                                    ±1.1
#
#    HOUSING OCCUPANCY!!Homeowner vacancy rate  \
# 0                                        NaN
# 1                                        2.3
# 2                                       ±0.8
# 3                                        (X)
# 4                                        (X)
# 5                                        NaN
# 6                                        2.6
# 7                                       ±0.5
# 8                                        (X)
# 9                                        (X)
# 10                                       NaN
# 11                                       3.0
# 12                                      ±1.0
# 13                                       (X)
# 14                                       (X)
# 15                                       NaN
# 16                                       1.3
# 17                                      ±0.3
# 18                                       (X)
# 19                                       (X)
# 20                                       NaN
# 21                                       2.1
# 22                                      ±0.8
# 23                                       (X)
# 24                                       (X)
#
#    HOUSING OCCUPANCY!!Rental vacancy rate  UNITS IN STRUCTURE  \
# 0                                     NaN                 NaN
# 1                                     3.1                 NaN
# 2                                    ±0.5                 NaN
# 3                                     (X)                 NaN
# 4                                     (X)                 NaN
# 5                                     NaN                 NaN
# 6                                     3.8                 NaN
# 7                                    ±0.4                 NaN
# 8                                     (X)                 NaN
# 9                                     (X)                 NaN
# 10                                    NaN                 NaN
# 11                                    3.8                 NaN
# 12                                   ±0.6                 NaN
# 13                                    (X)                 NaN
# 14                                    (X)                 NaN
# 15                                    NaN                 NaN
# 16                                    2.9                 NaN
# 17                                   ±0.4                 NaN
# 18                                    (X)                 NaN
# 19                                    (X)                 NaN
# 20                                    NaN                 NaN
# 21                                    6.7                 NaN
# 22                                   ±1.6                 NaN
# 23                                    (X)                 NaN
# 24                                    (X)                 NaN
#
#    UNITS IN STRUCTURE!!Total housing units  \
# 0                                      NaN
# 1                                  514,051
# 2                                   ±1,413
# 3                                  514,051
# 4                                      (X)
# 5                                      NaN
# 6                                1,003,114
# 7                                   ±1,441
# 8                                1,003,114
# 9                                      (X)
# 10                                     NaN
# 11                                 850,490
# 12                                  ±3,152
# 13                                 850,490
# 14                                     (X)
# 15                                     NaN
# 16                                 840,147
# 17                                    ±952
# 18                                 840,147
# 19                                     (X)
# 20                                     NaN
# 21                                 177,479
# 22                                    ±586
# 23                                 177,479
# 24                                     (X)
#
#    UNITS IN STRUCTURE!!1-unit, detached  ... GROSS RENT!!No rent paid  \
# 0                                   NaN  ...                      NaN
# 1                                30,361  ...                    6,799
# 2                                ±2,523  ...                   ±1,481
# 3                                  5.9%  ...                      (X)
# 4                                  ±0.5  ...                      (X)
# 5                                   NaN  ...                      NaN
# 6                                57,037  ...                   18,768
# 7                                ±2,730  ...                   ±2,065
# 8                                  5.7%  ...                      (X)
# 9                                  ±0.3  ...                      (X)
# 10                                  NaN  ...                      NaN
# 11                                5,235  ...                   11,028
# 12                               ±1,419  ...                   ±2,228
# 13                                 0.6%  ...                      (X)
# 14                                 ±0.2  ...                      (X)
# 15                                  NaN  ...                      NaN
# 16                              161,184  ...                   13,728
# 17                               ±4,246  ...                   ±1,637
# 18                                19.2%  ...                      (X)
# 19                                 ±0.5  ...                      (X)
# 20                                  NaN  ...                      NaN
# 21                               60,275  ...                    2,653
# 22                               ±2,904  ...                     ±754
# 23                                34.0%  ...                      (X)
# 24                                 ±1.6  ...                      (X)
#
#    GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#    GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)  \
# 0                                                 NaN
# 1                                             370,186
# 2                                              ±4,550
# 3                                             370,186
# 4                                                 (X)
# 5                                                 NaN
# 6                                             608,898
# 7                                              ±6,778
# 8                                             608,898
# 9                                                 (X)
# 10                                                NaN
# 11                                            557,868
# 12                                             ±9,666
# 13                                            557,868
# 14                                                (X)
# 15                                                NaN
# 16                                            416,395
# 17                                             ±5,560
# 18                                            416,395
# 19                                                (X)
# 20                                                NaN
# 21                                             49,611
# 22                                             ±3,040
# 23                                             49,611
# 24                                                (X)
#
#    GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Less than 15.0 percent  \
# 0                                                 NaN
# 1                                              35,354
# 2                                              ±3,161
# 3                                                9.6%
# 4                                                ±0.8
# 5                                                 NaN
# 6                                              68,256
# 7                                              ±3,493
# 8                                               11.2%
# 9                                                ±0.6
# 10                                                NaN
# 11                                             98,151
# 12                                             ±5,649
# 13                                              17.6%
# 14                                               ±1.0
# 15                                                NaN
# 16                                             43,869
# 17                                             ±3,231
# 18                                              10.5%
# 19                                               ±0.8
# 20                                                NaN
# 21                                              5,646
# 22                                             ±1,305
# 23                                              11.4%
# 24                                               ±2.5
#
#    GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!15.0 to 19.9 percent  \
# 0                                                 NaN
# 1                                              36,693
# 2                                              ±2,681
# 3                                                9.9%
# 4                                                ±0.7
# 5                                                 NaN
# 6                                              64,318
# 7                                              ±4,604
# 8                                               10.6%
# 9                                                ±0.7
# 10                                                NaN
# 11                                             62,480
# 12                                             ±4,814
# 13                                              11.2%
# 14                                               ±0.9
# 15                                                NaN
# 16                                             44,988
# 17                                             ±3,055
# 18                                              10.8%
# 19                                               ±0.7
# 20                                                NaN
# 21                                              6,120
# 22                                             ±1,354
# 23                                              12.3%
# 24                                               ±2.6
#
#    GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!20.0 to 24.9 percent  \
# 0                                                 NaN
# 1                                              32,090
# 2                                              ±2,110
# 3                                                8.7%
# 4                                                ±0.6
# 5                                                 NaN
# 6                                              69,573
# 7                                              ±4,081
# 8                                               11.4%
# 9                                                ±0.6
# 10                                                NaN
# 11                                             67,833
# 12                                             ±6,020
# 13                                              12.2%
# 14                                               ±1.1
# 15                                                NaN
# 16                                             49,384
# 17                                             ±3,317
# 18                                              11.9%
# 19                                               ±0.8
# 20                                                NaN
# 21                                              7,264
# 22                                             ±1,506
# 23                                              14.6%
# 24                                               ±2.7
#
#    GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!25.0 to 29.9 percent  \
# 0                                                 NaN
# 1                                              38,332
# 2                                              ±3,523
# 3                                               10.4%
# 4                                                ±0.9
# 5                                                 NaN
# 6                                              72,166
# 7                                              ±3,255
# 8                                               11.9%
# 9                                                ±0.5
# 10                                                NaN
# 11                                             70,164
# 12                                             ±5,089
# 13                                              12.6%
# 14                                               ±0.9
# 15                                                NaN
# 16                                             43,198
# 17                                             ±3,543
# 18                                              10.4%
# 19                                               ±0.8
# 20                                                NaN
# 21                                              4,348
# 22                                               ±965
# 23                                               8.8%
# 24                                               ±2.0
#
#    GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!30.0 to 34.9 percent  \
# 0                                                 NaN
# 1                                              37,964
# 2                                              ±3,193
# 3                                               10.3%
# 4                                                ±0.9
# 5                                                 NaN
# 6                                              56,163
# 7                                              ±3,510
# 8                                                9.2%
# 9                                                ±0.6
# 10                                                NaN
# 11                                             50,532
# 12                                             ±4,666
# 13                                               9.1%
# 14                                               ±0.8
# 15                                                NaN
# 16                                             35,470
# 17                                             ±3,317
# 18                                               8.5%
# 19                                               ±0.8
# 20                                                NaN
# 21                                              2,959
# 22                                               ±858
# 23                                               6.0%
# 24                                               ±1.7
#
#     GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!35.0 percent or more  \
# 0                                                 NaN
# 1                                             189,753
# 2                                              ±5,119
# 3                                               51.3%
# 4                                                ±1.3
# 5                                                 NaN
# 6                                             278,422
# 7                                              ±6,754
# 8                                               45.7%
# 9                                                ±1.0
# 10                                                NaN
# 11                                            208,708
# 12                                             ±8,091
# 13                                              37.4%
# 14                                               ±1.3
# 15                                                NaN
# 16                                            199,486
# 17                                             ±5,488
# 18                                              47.9%
# 19                                               ±1.2
# 20                                                NaN
# 21                                             23,274
# 22                                             ±2,225
# 23                                              46.9%
# 24                                               ±3.6
#
#    GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Not computed
# 0                                                 NaN
# 1                                              14,676
# 2                                              ±2,091
# 3                                                 (X)
# 4                                                 (X)
# 5                                                 NaN
# 6                                              37,133
# 7                                              ±3,020
# 8                                                 (X)
# 9                                                 (X)
# 10                                                NaN
# 11                                             24,159
# 12                                             ±3,380
# 13                                                (X)
# 14                                                (X)
# 15                                                NaN
# 16                                             23,928
# 17                                             ±2,217
# 18                                                (X)
# 19                                                (X)
# 20                                                NaN
# 21                                              3,835
# 22                                               ±957
# 23                                                (X)
# 24                                                (X)
#
# [25 rows x 159 columns]

# %%
df.keys()
# Out:
# Index(['Label (Grouping)', 'HOUSING OCCUPANCY',
#        'HOUSING OCCUPANCY!!Total housing units',
#        'HOUSING OCCUPANCY!!Total housing units!!Occupied housing units',
#        'HOUSING OCCUPANCY!!Total housing units!!Vacant housing units',
#        'HOUSING OCCUPANCY!!Total housing units!!Homeowner vacancy rate',
#        'HOUSING OCCUPANCY!!Total housing units!!Rental vacancy rate',
#        'UNITS IN STRUCTURE', 'UNITS IN STRUCTURE!!Total housing units',
#        'UNITS IN STRUCTURE!!Total housing units!!1-unit, detached',
#        ...
#        'GROSS RENT!!Occupied units paying rent!!No rent paid',
#        'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)',
#        'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)',
#        'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!Less than 15.0 percent',
#        'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!15.0 to 19.9 percent',
#        'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!20.0 to 24.9 percent',
#        'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!25.0 to 29.9 percent',
#        'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!30.0 to 34.9 percent',
#        'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!35.0 percent or more',
#        'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)!!Occupied units paying rent (excluding units where GRAPI cannot be computed)!!Not computed'],
#       dtype='object', length=161)

# %%
#df.at[5, 'HOUSING OCCUPANCY'] = 'BRONX'
x=len(df)
borough= ['N/A', 
          'BRONX',
          'BROOKLYN',
          'MANHATTAN',
          'QUEENS',
          'STATEN ISLAND']

for i in range (1,x):        
    y = math.ceil(i/5)
    df.at[i,'HOUSING OCCUPANCY'] = borough[y]

# %%
copy_cols=["Label (Grouping)","HOUSING OCCUPANCY","HOUSING OCCUPANCY!!Total housing units",
           "HOUSING OCCUPANCY!!Total housing units!!Occupied housing units","HOUSING OCCUPANCY!!Total housing units!!Vacant housing units",
           "ROOMS!!Total housing units!!1 room","ROOMS!!Total housing units!!2 rooms",
           "ROOMS!!Total housing units!!3 rooms","ROOMS!!Total housing units!!4 rooms",
           "ROOMS!!Total housing units!!5 rooms","ROOMS!!Total housing units!!6 rooms",
           "ROOMS!!Total housing units!!7 rooms","ROOMS!!Total housing units!!8 rooms",
           "ROOMS!!Total housing units!!9 rooms or more","ROOMS!!Total housing units!!Median rooms",
           "BEDROOMS!!Total housing units!!No bedroom","BEDROOMS!!Total housing units!!1 bedroom",
           "BEDROOMS!!Total housing units!!2 bedrooms","BEDROOMS!!Total housing units!!3 bedrooms",
           "BEDROOMS!!Total housing units!!4 bedrooms","BEDROOMS!!Total housing units!!5 or more bedrooms",
#           "HOUSING TENURE!!Occupied housing units",
           "HOUSING TENURE!!Occupied housing units!!Owner-occupied",
           "HOUSING TENURE!!Occupied housing units!!Renter-occupied",
           "OCCUPANTS PER ROOM!!Occupied housing units!!1.00 or less",
           "OCCUPANTS PER ROOM!!Occupied housing units!!1.01 to 1.50",
           "OCCUPANTS PER ROOM!!Occupied housing units!!1.51 or more","VALUE!!Owner-occupied units",
           "VALUE!!Owner-occupied units!!Less than $50,000","VALUE!!Owner-occupied units!!$50,000 to $99,999",
           "VALUE!!Owner-occupied units!!$100,000 to $149,999","VALUE!!Owner-occupied units!!$150,000 to $199,999",
           "VALUE!!Owner-occupied units!!$200,000 to $299,999","VALUE!!Owner-occupied units!!$300,000 to $499,999",
           "VALUE!!Owner-occupied units!!$500,000 to $999,999","VALUE!!Owner-occupied units!!$1,000,000 or more",
           "VALUE!!Owner-occupied units!!Median (dollars)","GROSS RENT!!Occupied units paying rent",
#           "GROSS RENT!!Occupied units paying rent!!Less than $500",
#           "GROSS RENT!!Occupied units paying rent!!$500 to $999",
#           "GROSS RENT!!Occupied units paying rent!!$1,000 to $1,499",
#           "GROSS RENT!!Occupied units paying rent!!$1,500 to $1,999",
#           "GROSS RENT!!Occupied units paying rent!!$2,000 to $2,499",
#           "GROSS RENT!!Occupied units paying rent!!$2,500 to $2,999",
#           "GROSS RENT!!Occupied units paying rent!!$3,000 or more",
           "GROSS RENT!!Occupied units paying rent!!Median (dollars)"]

read_cols=['data/ACS_2021.csv', 'data/ACS_2020.csv',
           'data/ACS_2019.csv','data/ACS_2018.csv',
           'data/ACS_2017.csv','data/ACS_2016.csv',
           'data/ACS_2015.csv','data/ACS_2014.csv',
           'data/ACS_2013.csv',]
            #'data/ACS_2012.csv',
#           'data/ACS_2011.csv','data/ACS_2010.csv',]

year_cols=['N/A','2021','2020','2019','2018','2017','2016',
           '2015','2014','2013',
           '2012','2011','2010']

rename_cols={"Label (Grouping)" : 'label',
             "HOUSING OCCUPANCY" : 'borough',
             "HOUSING OCCUPANCY!!Total housing units":'total_housing_units',
           "HOUSING OCCUPANCY!!Total housing units!!Occupied housing units":'occupied_housing_units',
             "HOUSING OCCUPANCY!!Total housing units!!Vacant housing units":'vacant_housing_units',
           "ROOMS!!Total housing units!!1 room":'1_room_units',
             "ROOMS!!Total housing units!!2 rooms":'1_room_units',
           "ROOMS!!Total housing units!!3 rooms":'1_room_units',
             "ROOMS!!Total housing units!!4 rooms":'1_room_units',
           "ROOMS!!Total housing units!!5 rooms":'1_room_units',
             "ROOMS!!Total housing units!!6 rooms":'1_room_units',
           "ROOMS!!Total housing units!!7 rooms":'1_room_units',
             "ROOMS!!Total housing units!!8 rooms":'1_room_units',
           "ROOMS!!Total housing units!!9 rooms or more":'1_room_units',
             "ROOMS!!Total housing units!!Median rooms":'unit_median_rooms',
           "BEDROOMS!!Total housing units!!No bedroom":'unit_no_bedrooms',
             "BEDROOMS!!Total housing units!!1 bedroom":'unit_1_bedrooms',
           "BEDROOMS!!Total housing units!!2 bedrooms":'unit_2_bedrooms',
             "BEDROOMS!!Total housing units!!3 bedrooms":'unit_3_bedrooms',
           "BEDROOMS!!Total housing units!!4 bedrooms":'unit_4_bedrooms',
             "BEDROOMS!!Total housing units!!5 or more bedrooms":'unit_5+_bedrooms',
#           "HOUSING TENURE!!Occupied housing units":'',
             "HOUSING TENURE!!Occupied housing units!!Owner-occupied":'owner_occupied_units',
           "HOUSING TENURE!!Occupied housing units!!Renter-occupied":'renter_occupied_units',
           "OCCUPANTS PER ROOM!!Occupied housing units!!1.00 or less":'occupants_per_room_<=1',
           "OCCUPANTS PER ROOM!!Occupied housing units!!1.01 to 1.50":'occupants_per_room_1-1.5',
           "OCCUPANTS PER ROOM!!Occupied housing units!!1.51 or more":'occupants_per_room_>=1.5',
             "VALUE!!Owner-occupied units":'owned_units',
           "VALUE!!Owner-occupied units!!Less than $50,000": 'x_<_$50,000',
             "VALUE!!Owner-occupied units!!$50,000 to $99,999": '$50,000_x_<_$99,999',
           "VALUE!!Owner-occupied units!!$100,000 to $149,999": '$100,000_x_<_$149,999',
             "VALUE!!Owner-occupied units!!$150,000 to $199,999": '$150,000_x_<_$199,999',
           "VALUE!!Owner-occupied units!!$200,000 to $299,999": '$200,000_x_<_$299,999',
             "VALUE!!Owner-occupied units!!$300,000 to $499,999": '$300,000_x_<_$499,999',
           "VALUE!!Owner-occupied units!!$500,000 to $999,999": '$500,000_x_<_$999,999',
             "VALUE!!Owner-occupied units!!$1,000,000 or more": 'x_>_$1,000,000',
           "VALUE!!Owner-occupied units!!Median (dollars)":'owned_median_value',
             "GROSS RENT!!Occupied units paying rent":'rented_units',
#           "GROSS RENT!!Occupied units paying rent!!Less than $500",
#           "GROSS RENT!!Occupied units paying rent!!$500 to $999",
#           "GROSS RENT!!Occupied units paying rent!!$1,000 to $1,499",
#           "GROSS RENT!!Occupied units paying rent!!$1,500 to $1,999",
#           "GROSS RENT!!Occupied units paying rent!!$2,000 to $2,499",
#           "GROSS RENT!!Occupied units paying rent!!$2,500 to $2,999",
#           "GROSS RENT!!Occupied units paying rent!!$3,000 or more",
           "GROSS RENT!!Occupied units paying rent!!Median (dollars)":'rent_median_value'}

borough= ['N/A', 
          'BRONX',
          'BROOKLYN',
          'MANHATTAN',
          'QUEENS',
          'STATEN ISLAND']
counter = 0
for item in read_cols:
    counter += 1
    x=0
    x2=0
    y=0
    y2=0
    if item == read_cols[0]:
        df = pd.read_csv(item, skipinitialspace=True, usecols=copy_cols, sep=',', low_memory = False)
        x=len(df)
        for i in range (1,x):
            y = math.ceil(i/5)
            df.at[i,'HOUSING OCCUPANCY'] = borough[y]
        df['year'] = year_cols[counter]
        df.drop(labels = [0,5,10,15,20], axis = 0 , inplace = True )
    else:
        temp = pd.read_csv(item, skipinitialspace=True, usecols=copy_cols, sep=',', low_memory = False)
        x2 = len(temp)
        for g in range (1,x2):
            y2 = math.ceil(g/5)
            temp.at[g,'HOUSING OCCUPANCY'] = borough[y2]
        temp['year'] = year_cols[counter]
        temp.drop(labels = [0,5,10,15,20], axis = 0 , inplace = True)
        df = pd.concat([df, temp], sort=False)

df
# Out:
#                Label (Grouping) HOUSING OCCUPANCY  \
# 1                      Estimate             BRONX
# 2               Margin of Error             BRONX
# 3                       Percent             BRONX
# 4       Percent Margin of Error             BRONX
# 6                      Estimate          BROOKLYN
# ..                          ...               ...
# 19      Percent Margin of Error            QUEENS
# 21                     Estimate     STATEN ISLAND
# 22              Margin of Error     STATEN ISLAND
# 23                      Percent     STATEN ISLAND
# 24      Percent Margin of Error     STATEN ISLAND
#
#    HOUSING OCCUPANCY!!Total housing units  \
# 1                                 552,421
# 2                                  ±2,001
# 3                                 552,421
# 4                                     (X)
# 6                               1,085,993
# ..                                    ...
# 19                                    (X)
# 21                                178,035
# 22                                   ±546
# 23                                178,035
# 24                                    (X)
#
#    HOUSING OCCUPANCY!!Total housing units!!Occupied housing units  \
# 1                                             533,004
# 2                                              ±2,823
# 3                                               96.5%
# 4                                                ±0.4
# 6                                           1,001,868
# ..                                                ...
# 19                                               ±0.5
# 21                                            167,629
# 22                                             ±1,823
# 23                                              94.2%
# 24                                               ±1.0
#
#    HOUSING OCCUPANCY!!Total housing units!!Vacant housing units  \
# 1                                              19,417
# 2                                              ±2,160
# 3                                                3.5%
# 4                                                ±0.4
# 6                                              84,125
# ..                                                ...
# 19                                               ±0.5
# 21                                             10,406
# 22                                             ±1,759
# 23                                               5.8%
# 24                                               ±1.0
#
#    ROOMS!!Total housing units!!1 room ROOMS!!Total housing units!!2 rooms  \
# 1                              41,219                              26,963
# 2                              ±4,314                              ±3,395
# 3                                7.5%                                4.9%
# 4                                ±0.8                                ±0.6
# 6                              72,187                              86,381
# ..                                ...                                 ...
# 19                               ±0.4                                ±0.3
# 21                              3,303                               4,244
# 22                             ±1,048                              ±1,042
# 23                               1.9%                                2.4%
# 24                               ±0.6                                ±0.6
#
#    ROOMS!!Total housing units!!3 rooms ROOMS!!Total housing units!!4 rooms  \
# 1                              146,200                             157,613
# 2                               ±7,554                              ±7,344
# 3                                26.5%                               28.5%
# 4                                 ±1.3                                ±1.3
# 6                              255,228                             290,858
# ..                                 ...                                 ...
# 19                                ±0.9                                ±0.8
# 21                              21,523                              26,505
# 22                              ±2,346                              ±2,746
# 23                               12.1%                               14.9%
# 24                                ±1.3                                ±1.5
#
#    ROOMS!!Total housing units!!5 rooms  ...  \
# 1                              105,460  ...
# 2                               ±6,316  ...
# 3                                19.1%  ...
# 4                                 ±1.1  ...
# 6                              185,074  ...
# ..                                 ...  ...
# 19                                ±0.7  ...
# 21                              31,241  ...
# 22                              ±2,699  ...
# 23                               17.5%  ...
# 24                                ±1.5  ...
#
#    VALUE!!Owner-occupied units!!$100,000 to $149,999  \
# 1                                              3,087
# 2                                               ±944
# 3                                               3.0%
# 4                                               ±0.9
# 6                                              5,390
# ..                                               ...
# 19                                              ±0.4
# 21                                             1,679
# 22                                              ±614
# 23                                              1.5%
# 24                                              ±0.5
#
#    VALUE!!Owner-occupied units!!$150,000 to $199,999  \
# 1                                              5,314
# 2                                             ±1,503
# 3                                               5.1%
# 4                                               ±1.4
# 6                                              5,226
# ..                                               ...
# 19                                              ±0.5
# 21                                             1,304
# 22                                              ±552
# 23                                              1.2%
# 24                                              ±0.5
#
#    VALUE!!Owner-occupied units!!$200,000 to $299,999  \
# 1                                             10,041
# 2                                             ±1,826
# 3                                               9.6%
# 4                                               ±1.7
# 6                                             11,733
# ..                                               ...
# 19                                              ±0.9
# 21                                            12,943
# 22                                            ±1,590
# 23                                             11.5%
# 24                                              ±1.4
#
#    VALUE!!Owner-occupied units!!$300,000 to $499,999  \
# 1                                             19,188
# 2                                             ±2,209
# 3                                              18.4%
# 4                                               ±1.9
# 6                                             31,746
# ..                                               ...
# 19                                              ±1.0
# 21                                            54,730
# 22                                            ±3,056
# 23                                             48.4%
# 24                                              ±2.2
#
#    VALUE!!Owner-occupied units!!$500,000 to $999,999  \
# 1                                             45,604
# 2                                             ±3,459
# 3                                              43.7%
# 4                                               ±2.5
# 6                                            133,037
# ..                                               ...
# 19                                              ±1.0
# 21                                            35,192
# 22                                            ±2,637
# 23                                             31.1%
# 24                                              ±2.2
#
#    VALUE!!Owner-occupied units!!$1,000,000 or more  \
# 1                                            3,542
# 2                                           ±1,063
# 3                                             3.4%
# 4                                             ±1.0
# 6                                          101,586
# ..                                             ...
# 19                                            ±0.4
# 21                                           2,676
# 22                                            ±743
# 23                                            2.4%
# 24                                            ±0.7
#
#    VALUE!!Owner-occupied units!!Median (dollars)  \
# 1                                        465,000
# 2                                        ±28,221
# 3                                            (X)
# 4                                            (X)
# 6                                        793,300
# ..                                           ...
# 19                                           (X)
# 21                                       432,600
# 22                                        ±7,772
# 23                                           (X)
# 24                                           (X)
#
#    GROSS RENT!!Occupied units paying rent  \
# 1                                 421,250
# 2                                  ±5,773
# 3                                 421,250
# 4                                     (X)
# 6                                 681,618
# ..                                    ...
# 19                                    (X)
# 21                                 52,395
# 22                                 ±3,400
# 23                                 52,395
# 24                                    (X)
#
#    GROSS RENT!!Occupied units paying rent!!Median (dollars)  year
# 1                                               1,313        2021
# 2                                                 ±20        2021
# 3                                                 (X)        2021
# 4                                                 (X)        2021
# 6                                               1,628        2021
# ..                                                ...         ...
# 19                                                (X)        2013
# 21                                              1,161        2013
# 22                                                ±44        2013
# 23                                                (X)        2013
# 24                                                (X)        2013
#
# [180 rows x 39 columns]

# %%
df=df.rename(columns = rename_cols)
df
# Out:
#                           label        borough total_housing_units  \
# 1                      Estimate          BRONX             552,421
# 2               Margin of Error          BRONX              ±2,001
# 3                       Percent          BRONX             552,421
# 4       Percent Margin of Error          BRONX                 (X)
# 6                      Estimate       BROOKLYN           1,085,993
# ..                          ...            ...                 ...
# 19      Percent Margin of Error         QUEENS                 (X)
# 21                     Estimate  STATEN ISLAND             178,035
# 22              Margin of Error  STATEN ISLAND                ±546
# 23                      Percent  STATEN ISLAND             178,035
# 24      Percent Margin of Error  STATEN ISLAND                 (X)
#
#    occupied_housing_units vacant_housing_units 1_room_units 1_room_units  \
# 1                 533,004               19,417       41,219       26,963
# 2                  ±2,823               ±2,160       ±4,314       ±3,395
# 3                   96.5%                 3.5%         7.5%         4.9%
# 4                    ±0.4                 ±0.4         ±0.8         ±0.6
# 6               1,001,868               84,125       72,187       86,381
# ..                    ...                  ...          ...          ...
# 19                   ±0.5                 ±0.5         ±0.4         ±0.3
# 21                167,629               10,406        3,303        4,244
# 22                 ±1,823               ±1,759       ±1,048       ±1,042
# 23                  94.2%                 5.8%         1.9%         2.4%
# 24                   ±1.0                 ±1.0         ±0.6         ±0.6
#
#    1_room_units 1_room_units 1_room_units  ... $100,000_x_<_$149,999  \
# 1       146,200      157,613      105,460  ...                 3,087
# 2        ±7,554       ±7,344       ±6,316  ...                  ±944
# 3         26.5%        28.5%        19.1%  ...                  3.0%
# 4          ±1.3         ±1.3         ±1.1  ...                  ±0.9
# 6       255,228      290,858      185,074  ...                 5,390
# ..          ...          ...          ...  ...                   ...
# 19         ±0.9         ±0.8         ±0.7  ...                  ±0.4
# 21       21,523       26,505       31,241  ...                 1,679
# 22       ±2,346       ±2,746       ±2,699  ...                  ±614
# 23        12.1%        14.9%        17.5%  ...                  1.5%
# 24         ±1.3         ±1.5         ±1.5  ...                  ±0.5
#
#    $150,000_x_<_$199,999 $200,000_x_<_$299,999 $300,000_x_<_$499,999  \
# 1                  5,314                10,041                19,188
# 2                 ±1,503                ±1,826                ±2,209
# 3                   5.1%                  9.6%                 18.4%
# 4                   ±1.4                  ±1.7                  ±1.9
# 6                  5,226                11,733                31,746
# ..                   ...                   ...                   ...
# 19                  ±0.5                  ±0.9                  ±1.0
# 21                 1,304                12,943                54,730
# 22                  ±552                ±1,590                ±3,056
# 23                  1.2%                 11.5%                 48.4%
# 24                  ±0.5                  ±1.4                  ±2.2
#
#    $500,000_x_<_$999,999 x_>_$1,000,000 owned_median_value rented_units  \
# 1                 45,604          3,542            465,000      421,250
# 2                 ±3,459         ±1,063            ±28,221       ±5,773
# 3                  43.7%           3.4%                (X)      421,250
# 4                   ±2.5           ±1.0                (X)          (X)
# 6                133,037        101,586            793,300      681,618
# ..                   ...            ...                ...          ...
# 19                  ±1.0           ±0.4                (X)          (X)
# 21                35,192          2,676            432,600       52,395
# 22                ±2,637           ±743             ±7,772       ±3,400
# 23                 31.1%           2.4%                (X)       52,395
# 24                  ±2.2           ±0.7                (X)          (X)
#
#    rent_median_value  year
# 1              1,313  2021
# 2                ±20  2021
# 3                (X)  2021
# 4                (X)  2021
# 6              1,628  2021
# ..               ...   ...
# 19               (X)  2013
# 21             1,161  2013
# 22               ±44  2013
# 23               (X)  2013
# 24               (X)  2013
#
# [180 rows x 39 columns]

# %%
estimate_df =
moe_df
percent_df
percent_df

# %%
df.groupby(['HOUSING OCCUPANCY'])['Label (Grouping)'].count()
# Out:
# HOUSING OCCUPANCY
# BRONX            36
# BROOKLYN         36
# MANHATTAN        36
# QUEENS           36
# STATEN ISLAND    36
# Name: Label (Grouping), dtype: int64
