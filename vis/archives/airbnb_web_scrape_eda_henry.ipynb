# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure

# %%
df = pd.read_csv('../data/clean/airbnb_web_scraped.csv')
# Out:
#                        title  \
# 0      Apartment in New York
# 1      Apartment in Brooklyn
# 2   Private room in New York
# 3   Private room in New York
# 4   Private room in New York
# ..                       ...
# 60  Private room in Brooklyn
# 61    Hotel room in New York
# 62     Apartment in Brooklyn
# 63  Private room in Brooklyn
# 64  Private room in New York
#
#                                          description      num_beds price_val  \
# 0        ✨Love SUITE & SPA | private outdoor HOT TUB   1 queen bed      $119
# 1      Beautiful Penthouse Suite with skyline views!         1 bed      $500
# 2     Minimal room 4 SofaBed + loft bed in Manhattan        2 beds       $79
# 3                              Room By Central Park!  1 single bed       $91
# 4                             Terracotta Room in LES   1 queen bed       $85
# ..                                               ...           ...       ...
# ...
